# %% [markdown]
# # Проект "Телеком". Предсказание оттока клиентов

# %% [markdown]
# # Загрузка данных

# %% [markdown]
# ## Загрузка библиотек

# %%
# !pip install -q phik
# !pip install --upgrade -q scikit-learn
# !pip install -q category_encoders
# !pip install -q catboost
# !pip install -q lightgbm
# !pip install -q scikit-plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

import phik
from phik import phik_matrix
from phik.report import plot_correlation_matrix
from phik import report

import scikitplot as skplt
from sqlalchemy import create_engine

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,  precision_score, recall_score
from sklearn.metrics import roc_auc_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, precision_recall_curve, PrecisionRecallDisplay

from sklearn.preprocessing import OneHotEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import make_column_transformer, make_column_selector

from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from catboost import CatBoostClassifier
import lightgbm as lgb
from lightgbm import LGBMClassifier

import warnings
warnings.filterwarnings('ignore')

# Зададим глобальную переменную RANDOM_STATE
RANDOM_STATE = 100624

# %% [markdown]
# ## Подключение к базе данных

# %% [markdown]
# Подключимся к базе данных.

# %%
db_config = {
'user': 'praktikum_student',# имя пользователя,
'pwd': 'Sdf4$2;d-d30pp',# пароль,
'host': 'rc1b-wcoijxj3yxfsf3fs.mdb.yandexcloud.net',
'port': 6432,# порт подключения,
'db': 'data-science-final'# название базы данных,
}

# %%
# Создадим подключение к базе данных
connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(
    db_config['user'],
    db_config['pwd'],
    db_config['host'],
    db_config['port'],
    db_config['db']
)

# %%
# Создадим соединение
engine = create_engine(connection_string)

# %%
# Создадим пробный запрос
query = '''
SELECT "BeginDate"
FROM telecom.contract;
'''
pd.read_sql_query(query, con=engine).head(5)
# Out:
#     BeginDate
# 0  2020-02-01
# 1  2020-02-01
# 2  2018-08-09
# 3  2020-02-01
# 4  2019-01-26

# %% [markdown]
# # Исследовательский анализ и предобработка данных

# %% [markdown]
# * **Проанализируйте исходные данные. Проверьте:**
#
#     * Все ли таблицы содержат данные.
#     * Соответствует ли количество таблиц условию задачи.
#
# * **Для каждой таблицы:**
#
#     * Проведите исследовательский анализ данных: проверьте наличие пропусков и аномалий, изучите распределение признаков.
#     * Обработайте аномалии с учётом особенностей услуг телекоммуникации.

# %% [markdown]
# Проверим количество таблиц в базе данных

# %%
query = '''
SELECT table_name
  FROM information_schema.tables
 WHERE table_schema NOT IN ('information_schema','pg_catalog');
'''
df = pd.read_sql_query(query, con=engine)
df
# Out:
#         table_name
# 0         data_arc
# 1        data_bulk
# 2   data_bulk_time
# 3         data_gas
# 4        data_temp
# 5        data_wire
# 6   data_wire_time
# 7         contract
# 8         internet
# 9         personal
# 10           phone

# %% [markdown]
# Нужные нам таблице есть в базе: contract, internet, personal, phone.
# Далее загрузим каждую таблицу по-отдельности и познакомимся с их содержимым.

# %% [markdown]
# Загрузим таблицу **telecom.contract** c информацией о договорах клиентов

# %%
query = '''
SELECT *
FROM telecom.contract;
'''
telecom_contract_data = pd.read_sql_query(query, con=engine)
telecom_contract_data.head()
# Out:
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  4472-LVYGI  2020-02-01        None        Two year              Yes
# 1  3115-CZMZD  2020-02-01        None        Two year               No
# 2  3668-QPYBK  2018-08-09  2019-12-01  Month-to-month              Yes
# 3  5709-LVOEQ  2020-02-01        None        Two year               No
# 4  9237-HQITU  2019-01-26  2019-11-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges
# 0  Bank transfer (automatic)           52.55           NaN
# 1               Mailed check           20.25           NaN
# 2               Mailed check           53.85        108.15
# 3               Mailed check           80.85           NaN
# 4           Electronic check           70.70        151.65

# %%
telecom_contract_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           1869 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7032 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# **Таблица telecom.contract**
#
# * customerID — ID абонента;
# * BeginDate — дата начала действия договора;
# * EndDate — дата окончания действия договора;
# * Type — тип оплаты: раз в год-два или ежемесячно;
# * PaperlessBilling — электронный расчётный лист;
# * PaymentMethod — тип платежа;
# * MonthlyCharges — расходы за месяц;
# * TotalCharges — общие расходы абонента.
#
# В таблице telecom.contract 8 столбцов, 7043 строки/договоров.
#
# Внесем некоторые измнения:
# * Приведение названий признаков датафрейма к "змеиному стилю".
# * Заменим тип данных BeginDate и EndDate c object на date.

# %%
# Приведение названий признаков датафрейма к "змеиному стилю"
telecom_contract_data.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower() for i in telecom_contract_data.columns]
telecom_contract_data = telecom_contract_data.rename(columns={'customer_i_d':'customer_id'})

# Проверка полученных названий
telecom_contract_data.columns
# Out:
# Index(['customer_id', 'begin_date', 'end_date', 'type', 'paperless_billing',
#        'payment_method', 'monthly_charges', 'total_charges'],
#       dtype='object')

# %%
# Проверим корректность внесенных изменений
telecom_contract_data.dtypes
# Out:
# customer_id           object
# begin_date            object
# end_date              object
# type                  object
# paperless_billing     object
# payment_method        object
# monthly_charges      float64
# total_charges        float64
# dtype: object

# %% [markdown]
# Проверим данные на наличие пропущенных значений.

# %%
telecom_contract_data.isna().sum()
# Out:
# customer_id             0
# begin_date              0
# end_date             5174
# type                    0
# paperless_billing       0
# payment_method          0
# monthly_charges         0
# total_charges          11
# dtype: int64

# %% [markdown]
# * В колонке end_date - 5174 пропусков.
# * В колонке total_charges - 11 пропусков

# %% [markdown]
# Проверим строки, в которых есть пропуски в колонке 'total_charges'

# %%
# Фильтрация строк, где в колонке 'total_charges' есть NaN
missing_total_charges = telecom_contract_data[telecom_contract_data['total_charges'].isna()]
missing_total_charges
# Out:
#      customer_id  begin_date end_date      type paperless_billing  \
# 0     4472-LVYGI  2020-02-01     None  Two year               Yes
# 1     3115-CZMZD  2020-02-01     None  Two year                No
# 3     5709-LVOEQ  2020-02-01     None  Two year                No
# 6     4367-NUYAO  2020-02-01     None  Two year                No
# 7     1371-DWPAZ  2020-02-01     None  Two year                No
# 9     3213-VVOLG  2020-02-01     None  Two year                No
# 10    2923-ARZLG  2020-02-01     None  One year               Yes
# 11    2775-SEFEE  2020-02-01     None  Two year               Yes
# 4408  7644-OMVMY  2020-02-01     None  Two year                No
# 5160  2520-SGTTA  2020-02-01     None  Two year                No
# 6839  4075-WKNIU  2020-02-01     None  Two year                No
#
#                  payment_method  monthly_charges  total_charges
# 0     Bank transfer (automatic)            52.55            NaN
# 1                  Mailed check            20.25            NaN
# 3                  Mailed check            80.85            NaN
# 6                  Mailed check            25.75            NaN
# 7       Credit card (automatic)            56.05            NaN
# 9                  Mailed check            25.35            NaN
# 10                 Mailed check            19.70            NaN
# 11    Bank transfer (automatic)            61.90            NaN
# 4408               Mailed check            19.85            NaN
# 5160               Mailed check            20.00            NaN
# 6839               Mailed check            73.35            NaN

# %% [markdown]
# Если посмотреть на колонки begin_date	и end_date, то мы увидим, что все даты  равны дате вырузки базы 2020-02-01. То есть это клиенты, только что открывшие договор и у них еще нет расходов.
#
# Поэтому поставим значение 0 в строки с пропусками.

# %%
# Заполнение пропусков в поле 'total_charges' на 0. Эти клиенты еще не успели внести плату
telecom_contract_data['total_charges'] = telecom_contract_data['total_charges'].fillna(0)

# %% [markdown]
# Выделим в целевую переменную признак end_date.
#
# Целевой переменной в нашем исследовании является признак - разорвал ли клиент договор с телекоммуникационной компанией (0- нет, 1 - да).
#
# Если значение в колонке 'end_date' равно None, это будет означать, что договор еще не расторгнут.

# %%
def contract_terminated(end_date):
    if end_date is None:  # Если дата окончания не указана, то договор действует
        return 0
    else:
        return 1  # Иначе договор разорван

telecom_contract_data['contract_terminated'] = telecom_contract_data['end_date'].apply(contract_terminated)

telecom_contract_data.head()
# Out:
#   customer_id  begin_date    end_date            type paperless_billing  \
# 0  4472-LVYGI  2020-02-01        None        Two year               Yes
# 1  3115-CZMZD  2020-02-01        None        Two year                No
# 2  3668-QPYBK  2018-08-09  2019-12-01  Month-to-month               Yes
# 3  5709-LVOEQ  2020-02-01        None        Two year                No
# 4  9237-HQITU  2019-01-26  2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  \
# 0  Bank transfer (automatic)            52.55           0.00
# 1               Mailed check            20.25           0.00
# 2               Mailed check            53.85         108.15
# 3               Mailed check            80.85           0.00
# 4           Electronic check            70.70         151.65
#
#    contract_terminated
# 0                    0
# 1                    0
# 2                    1
# 3                    0
# 4                    1

# %% [markdown]
# Далее заполним пропуски в колонке 'end_date'.
# Предположим, что пропуски в 'end_date' связаны с тем, что клиенты еще не закрыли договор с компанией, это действующие клиенты. Поэтому поставим заглушку в виде даты вырузки базы 2020-02-01 (т.к. информация о договорах актуальна на 1 февраля 2020).

# %%
telecom_contract_data['end_date'] = telecom_contract_data['end_date'].fillna('2020-02-01')

# %%
# Поменять тип данных BeginDate и EndDate c object на date
telecom_contract_data['begin_date'] = pd.to_datetime(telecom_contract_data['begin_date'], format='%Y-%m-%d')
telecom_contract_data['end_date'] = pd.to_datetime(telecom_contract_data['end_date'], format='%Y-%m-%d')

# %%
telecom_contract_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          7043 non-null   object
#  1   begin_date           7043 non-null   datetime64[ns]
#  2   end_date             7043 non-null   datetime64[ns]
#  3   type                 7043 non-null   object
#  4   paperless_billing    7043 non-null   object
#  5   payment_method       7043 non-null   object
#  6   monthly_charges      7043 non-null   float64
#  7   total_charges        7043 non-null   float64
#  8   contract_terminated  7043 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(4)
# memory usage: 495.3+ KB

# %%
telecom_contract_data.isna().sum()
# Out:
# customer_id            0
# begin_date             0
# end_date               0
# type                   0
# paperless_billing      0
# payment_method         0
# monthly_charges        0
# total_charges          0
# contract_terminated    0
# dtype: int64

# %% [markdown]
# Избавились от пропусков в таблице telecom_contract_data.
# Проверим данные на явные дубликаты.

# %%
telecom_contract_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дублей нет.
# Посмотрим более подробную информацию о числовых данных в таблице telecom_contract_data с помощью метода describe().

# %%
num_col = ['monthly_charges', 'total_charges']
telecom_contract_data[num_col].describe().T
# Out:
#                   count         mean          std    min     25%      50%  \
# monthly_charges  7043.0    64.761692    30.090047  18.25   35.50    70.35
# total_charges    7043.0  2279.734304  2266.794470   0.00  398.55  1394.55
#
#                      75%      max
# monthly_charges    89.85   118.75
# total_charges    3786.60  8684.80

# %% [markdown]
# * Средние месячные траты (monthly_charges) клиентов равны 64.76. Min месячные расходы 18.25, а максимальные - 118.75.
# * Средние общие траты клиентов равны 2279.73. Min расходы 0, а максимальные - 8684.80.
#
# Построим дополнительно графики - гистограммы.

# %%
col = ['begin_date', 'end_date', 'monthly_charges', 'total_charges']

fig, axes = plt.subplots(nrows=len(col), figsize=(10, 15))

# Поворот меток по оси X под углом 45 градусов и добавление подписи осей
for i, ax in enumerate(axes):
    ax.hist(telecom_contract_data[col[i]], bins=30)
    ax.set_ylabel('Frequency')
    ax.set_xlabel(col[i])
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# * У нас есть исторические данные о клиентах за период с 2018-04 по 2020-01.
# Большее количество клиентов заключило договора ('begin_date') в период 2019-03 - 2019-05.
# * Большее количесвто клиентов в базе активны и имеют действующие договора (у таких клиентов в колонке 'end_date' значения равны дате выгрузки базы 2020-02-01). Остальные клиенты примерно в равной степени закрывали договора: 2019-10, 2019-11, 2019-12, 2020-01.
# * Большая часть клиентов имеют довольно маленькие ежемесячные траты 'monthly_charges' от 15-22.
# * Большая часть клиентов имеют общие траты 'total_charges' до 500.
#
#
# Построим столбчатые графики для категориальных значений (бинарных значений): 'type', 'payment_method', 'paperless_billing'.

# %%
# Список колонок для построения графиков
columns_to_plot = ['type', 'payment_method', 'paperless_billing']
titles = ['type', 'payment_method', 'paperless_billing']
colors = ['skyblue', 'lightgreen', 'salmon']

fig, axes = plt.subplots(1, 3, figsize=(12, 6))

# Цикл для создания столбчатых диаграмм
for ax, column, title, color in zip(axes.flatten(), columns_to_plot, titles, colors):
    telecom_contract_data[column].value_counts().plot(kind='bar', ax=ax, color=color)
    ax.set_title(title)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Большинство клиентов имеют ежемесячный тип оплаты 'type', прочие примерно в равной степени раз в год или два.
# * Большинство клиентов предпочитают расплачиваться 'payment_method' за услуги электронными чеками, остальные примерно в равной степени через почтовые чеки, авто-банковские переводы или автоматические платежи кредитной картой.
# * Большинство клиентов имеют электронный расчётный лист 'paperless_billing'.
#
# Теперь выгрузим таблицу с персональными данными клиентов **telecom.personal**.

# %%
query = '''
SELECT *
FROM telecom.personal;
'''
telecom_personal_data = pd.read_sql_query(query, con=engine)
telecom_personal_data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No

# %%
telecom_personal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# **Таблица telecom.personal**
#
# * customerID — ID пользователя;
# * gender — пол;
# * SeniorCitizen — является ли абонент пенсионером;
# * Partner — есть ли у абонента супруг или супруга;
# * Dependents — есть ли у абонента дети.
#
# В датасете telecom_personal_data 5 столбцов и 7043 строк/клиентов, что равно количеству строк/договоров в предыдущей таблице telecom_contract_data.
#
# Пропущенных значений нет.
#
# Внесем несколько изменений в данные:
#
# * Приведение названий признаков датафрейма к "змеиному стилю"

# %%
# Приведение названий признаков датафрейма к "змеиному стилю"
telecom_personal_data.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower() for i in telecom_personal_data.columns]
telecom_personal_data = telecom_personal_data.rename(columns={'customer_i_d':'customer_id'})

# Проверка полученных названий
telecom_personal_data.columns
# Out:
# Index(['customer_id', 'gender', 'senior_citizen', 'partner', 'dependents'], dtype='object')

# %% [markdown]
# Проверим датасет на явные дубликаты

# %%
telecom_personal_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дублей нет.
#
# Построим столбчатые графики для категориальных значений (бинарных в том числе).

# %%
# Список колонок для построения графиков
columns_to_plot = ['gender', 'senior_citizen', 'partner', 'dependents']
titles = ['gender', 'senior_citizen', 'partner', 'dependents']
colors = ['skyblue', 'lightgreen', 'salmon', 'orchid']

# Настройка фигуры и подграфиков
fig, axes = plt.subplots(2, 2, figsize=(8, 8))

# Цикл для создания столбчатых диаграмм
for ax, column, title, color in zip(axes.flatten(), columns_to_plot, titles, colors):
    telecom_personal_data[column].value_counts().plot(kind='bar', ax=ax, color=color)
    ax.set_title(title)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# * В датасете практически равное количество клиентов мужчин и женщин ('gender').
# * Большинство клиентов не пенсионеры (значение в колонке 'senior_citizen' - 0)
# * В датасете практически равное количество женатых и холостых клиентов, колонка 'partner' (холостых чуть больше)
# * Большинство клиентов 'dependents' без детей
#
#
# Выгрузим таблицу **telecom.internet** с информацией об интернет-услугах.

# %%
query = '''
SELECT *
FROM telecom.internet;
'''
telecom_internet_data = pd.read_sql_query(query, con=engine)
telecom_internet_data.head()
# Out:
#            c1               c2              c3            c4  \
# 0  customerID  InternetService  OnlineSecurity  OnlineBackup
# 1  7590-VHVEG              DSL              No           Yes
# 2  5575-GNVDE              DSL             Yes            No
# 3  3668-QPYBK              DSL             Yes           Yes
# 4  7795-CFOCW              DSL             Yes            No
#
#                  c5           c6           c7               c8
# 0  DeviceProtection  TechSupport  StreamingTV  StreamingMovies
# 1                No           No           No               No
# 2               Yes           No           No               No
# 3                No           No           No               No
# 4               Yes          Yes           No               No

# %% [markdown]
# Сразу удалим названия столбцов c1-c8, поставим понятные названия: 'customerID', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'.

# %%
# Выбираем строки начиная с первой (индекс 1) и все столбцы
telecom_internet_data = telecom_internet_data.iloc[1:, :].reset_index(drop=True)
telecom_internet_data.columns = ['customerID', 'InternetService', 'OnlineSecurity',
                                 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']
telecom_internet_data.head()
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No

# %%
telecom_internet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
#  1   InternetService   5517 non-null   object
#  2   OnlineSecurity    5517 non-null   object
#  3   OnlineBackup      5517 non-null   object
#  4   DeviceProtection  5517 non-null   object
#  5   TechSupport       5517 non-null   object
#  6   StreamingTV       5517 non-null   object
#  7   StreamingMovies   5517 non-null   object
# dtypes: object(8)
# memory usage: 344.9+ KB

# %% [markdown]
# **Таблица telecom.internet**
#
# * customerID — ID пользователя;
# * InternetService — тип подключения;
# * OnlineSecurity — блокировка опасных сайтов;
# * OnlineBackup — облачное хранилище файлов для резервного копирования данных;
# * DeviceProtection — антивирус;
# * TechSupport — выделенная линия технической поддержки;
# * StreamingTV — стриминговое телевидение;
# * StreamingMovies — каталог фильмов.
#
#
# Значений/клиентов меньше, чем в предыдущих таблицах - 5517 вместо 7043. Это говорит о том, что не все клиенты пользуются интернет-услугами компании.
#
# Пропущенных значений в датасете нет.
#
# Внесем некоторые изменения в данные:
#
# * Приведение названий признаков датафрейма к "змеиному стилю"
# * Заменим значения Yes/No в колонках 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies' на 1/0.

# %%
# Приведение названий признаков датафрейма к "змеиному стилю"
telecom_internet_data.columns = [re.sub(r'(?<!^)(?=[A-Z])', '_', i).lower() for i in telecom_internet_data.columns]
telecom_internet_data = telecom_internet_data.rename(columns={'customer_i_d':'customer_id'})

# Проверка полученных названий
telecom_internet_data.columns
# Out:
# Index(['customer_id', 'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support', 'streaming_t_v',
#        'streaming_movies'],
#       dtype='object')

# %% [markdown]
# Проверим данные на явные дубли.

# %%
telecom_internet_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дублей нет.
# Построим столбчатые диаграмы для категориальных значений (в том числе и для бинарных).

# %%
# Список колонок для построения графиков
columns_to_plot = ['internet_service', 'online_security', 'online_backup',
       'device_protection', 'tech_support', 'streaming_t_v',
       'streaming_movies']
titles = ['internet_service', 'online_security', 'online_backup',
       'device_protection', 'tech_support', 'streaming_t_v',
       'streaming_movies']
colors = ['skyblue', 'lightgreen', 'salmon', 'orchid', 'lightblue', 'lime', 'coral']

# Настройка фигуры и подграфиков
fig, axes = plt.subplots(7, 1, figsize=(10, 25))

# Цикл для создания столбчатых диаграмм
for ax, column, title, color in zip(axes.flatten(), columns_to_plot, titles, colors):
    telecom_internet_data[column].value_counts().plot(kind='bar', ax=ax, color=color)
    ax.set_title(title)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# * У большинства клиентов тип интернет-подключения 'internet_service' - fiber optic.
# * Большинство клиентов не подключали опцию блокировка опасных сайтов 'online_security'.
# * Большинство клиентов не подключали опцию - облачное хранилище файлов для резервного копирования данных 'online_backup'
# * Большинство клиентов не подключали опцию антивирус 'device_protection'
# * Большинство клиентов не подключали опцию выделенная линия технической поддержки 'tech_support'
# * Примерно одинаковое количество клиентов пользуются/не пользуются стриминговым телевидением 'streaming_t_v'
# * Примерно одинаковое количество клиентов пользуются/не пользуются каталогом фильмов 'streaming_movies'

# %% [markdown]
# Загрузим последнюю таблицу с информацией об услугах телефонии **telecom.phone**

# %%
query = '''
SELECT *
FROM telecom.phone;
'''
telecom_phone_data = pd.read_sql_query(query, con=engine)
telecom_phone_data.head()
# Out:
#            c1             c2
# 0  customerID  MultipleLines
# 1  5575-GNVDE             No
# 2  3668-QPYBK             No
# 3  9237-HQITU             No
# 4  9305-CDSKC            Yes

# %% [markdown]
# Сразу удалим названия столбцов c1-c2, чтобы оставить понятные названия: 'customerID', 'MultipleLines'.

# %%
# Выбираем строки начиная с первой (индекс 1) и все столбцы
telecom_phone_data = telecom_phone_data.iloc[1:, :].reset_index(drop=True)
telecom_phone_data.columns = ['customerID', 'MultipleLines']
telecom_phone_data.head()
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes

# %%
telecom_phone_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB

# %% [markdown]
# Таблица **telecom_phone_data**:
#
# * customerID — ID пользователя;
# * MultipleLines — подключение телефона к нескольким линиям одновременно.
#
# В датасете 2 колонки и 6361 строка - меньше, чем в таблице с договорами telecom.contract и персональными данными telecom.personal, это говорит о том, что не все клиенты подключали услуги телефонии.
#
# Пропущенных значений в датасете нет.
#
# Внесем некоторые изменения в данные:
#
# * Приведение названий признаков датафрейма к "змеиному стилю"

# %%
telecom_phone_data.rename(columns={'customerID': 'customer_id', 'MultipleLines': 'multiple_lines'}, inplace=True)
telecom_phone_data.head()
# Out:
#   customer_id multiple_lines
# 0  5575-GNVDE             No
# 1  3668-QPYBK             No
# 2  9237-HQITU             No
# 3  9305-CDSKC            Yes
# 4  1452-KIOVK            Yes

# %% [markdown]
# Проверим датасет на явные дубликаты.

# %%
telecom_phone_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дублей нет.
# Построим столбчатый график для категориальных значений

# %%
plt.figure(figsize=(6, 4))
telecom_phone_data['multiple_lines'].value_counts().plot(kind='bar')
plt.title('multiple_lines')
plt.xlabel('multiple_lines')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Большинство клиентов не подключали телефоны к нескольким линиям одновременно.

# %% [markdown]
# ## Объединение таблиц

# %% [markdown]
# * **Объедините таблицы по ID клиента:**
#
#     * Каждому клиенту должно соответствовать одно наблюдение. При объединении учитывайте особенности услуг телекоммуникации.
#
#     * Попробуйте сгенерировать новые признаки, которые могут пригодиться при обучении. Например, рассчитайте длительность контракта абонента.
#     * Выделите в целевую переменную признак EndDate.
#     * Проведите исследовательский анализ данных объединённой таблицы, при необходимости заполните пропуски и визуализируйте распределение каждого признака.
#     * Визуализируйте соотношение ушедших и оставшихся клиентов для каждого признака.
#     * Проведите корреляционный анализ.

# %% [markdown]
# Объединим 4 таблицы по ID клиента:
#
# * telecom_contract_data
# * telecom_personal_data
# * telecom_internet_data
# * telecom_phone_data

# %%
# Объединение датафреймов
data = telecom_contract_data.merge(telecom_personal_data, on='customer_id')
data = data.merge(telecom_internet_data, how='left', on='customer_id')
data = data.merge(telecom_phone_data, how='left', on='customer_id')

data.shape
# Out:
# (7043, 21)

# %%
data.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  4472-LVYGI 2020-02-01 2020-02-01        Two year               Yes
# 1  3115-CZMZD 2020-02-01 2020-02-01        Two year                No
# 2  3668-QPYBK 2018-08-09 2019-12-01  Month-to-month               Yes
# 3  5709-LVOEQ 2020-02-01 2020-02-01        Two year                No
# 4  9237-HQITU 2019-01-26 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  \
# 0  Bank transfer (automatic)            52.55           0.00
# 1               Mailed check            20.25           0.00
# 2               Mailed check            53.85         108.15
# 3               Mailed check            80.85           0.00
# 4           Electronic check            70.70         151.65
#
#    contract_terminated  gender  ...  partner dependents internet_service  \
# 0                    0  Female  ...      Yes        Yes              DSL
# 1                    0    Male  ...       No        Yes              NaN
# 2                    1    Male  ...       No         No              DSL
# 3                    0  Female  ...      Yes        Yes              DSL
# 4                    1  Female  ...       No         No      Fiber optic
#
#   online_security online_backup device_protection tech_support streaming_t_v  \
# 0             Yes            No               Yes          Yes           Yes
# 1             NaN           NaN               NaN          NaN           NaN
# 2             Yes           Yes                No           No            No
# 3             Yes           Yes               Yes           No           Yes
# 4              No            No                No           No            No
#
#   streaming_movies multiple_lines
# 0               No            NaN
# 1              NaN             No
# 2               No             No
# 3              Yes             No
# 4               No             No
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          7043 non-null   object
#  1   begin_date           7043 non-null   datetime64[ns]
#  2   end_date             7043 non-null   datetime64[ns]
#  3   type                 7043 non-null   object
#  4   paperless_billing    7043 non-null   object
#  5   payment_method       7043 non-null   object
#  6   monthly_charges      7043 non-null   float64
#  7   total_charges        7043 non-null   float64
#  8   contract_terminated  7043 non-null   int64
#  9   gender               7043 non-null   object
#  10  senior_citizen       7043 non-null   int64
#  11  partner              7043 non-null   object
#  12  dependents           7043 non-null   object
#  13  internet_service     5517 non-null   object
#  14  online_security      5517 non-null   object
#  15  online_backup        5517 non-null   object
#  16  device_protection    5517 non-null   object
#  17  tech_support         5517 non-null   object
#  18  streaming_t_v        5517 non-null   object
#  19  streaming_movies     5517 non-null   object
#  20  multiple_lines       6361 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# Объединенная таблица data имеет 20 колонок и 7043 строк.

# %% [markdown]
# Проверим новый датасет на пропуски.

# %%
data.isna().sum()
# Out:
# customer_id               0
# begin_date                0
# end_date                  0
# type                      0
# paperless_billing         0
# payment_method            0
# monthly_charges           0
# total_charges             0
# contract_terminated       0
# gender                    0
# senior_citizen            0
# partner                   0
# dependents                0
# internet_service       1526
# online_security        1526
# online_backup          1526
# device_protection      1526
# tech_support           1526
# streaming_t_v          1526
# streaming_movies       1526
# multiple_lines          682
# dtype: int64

# %% [markdown]
# В колонках связанных с услугами интернета и телефонии есть пропуски. Это говорит о том, что некоторые клиенты не подключали интернет услуги или телефонию.
#
# Поэтому мы можем заполнить пропуски датафрейма заглушкой 'No Internet' для тех, у кого не подключен интернет и 'No Telephony' для тех, у кого не подключена телефония.

# %%
# Заменим пропуски в колонках, связанных с интернет-услугами, на 'No Internet'
internet_cols = ['internet_service', 'online_security', 'online_backup', 
                 'device_protection', 'tech_support', 'streaming_t_v', 
                 'streaming_movies']
data[internet_cols] = data[internet_cols].fillna('No Internet')

# Заменим пропуски в колонке 'multiple_lines' на 'No Telephony'
data['multiple_lines'] = data['multiple_lines'].fillna('No Telephony')

# %%
data.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  4472-LVYGI 2020-02-01 2020-02-01        Two year               Yes
# 1  3115-CZMZD 2020-02-01 2020-02-01        Two year                No
# 2  3668-QPYBK 2018-08-09 2019-12-01  Month-to-month               Yes
# 3  5709-LVOEQ 2020-02-01 2020-02-01        Two year                No
# 4  9237-HQITU 2019-01-26 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  \
# 0  Bank transfer (automatic)            52.55           0.00
# 1               Mailed check            20.25           0.00
# 2               Mailed check            53.85         108.15
# 3               Mailed check            80.85           0.00
# 4           Electronic check            70.70         151.65
#
#    contract_terminated  gender  ...  partner dependents internet_service  \
# 0                    0  Female  ...      Yes        Yes              DSL
# 1                    0    Male  ...       No        Yes      No Internet
# 2                    1    Male  ...       No         No              DSL
# 3                    0  Female  ...      Yes        Yes              DSL
# 4                    1  Female  ...       No         No      Fiber optic
#
#   online_security online_backup device_protection tech_support streaming_t_v  \
# 0             Yes            No               Yes          Yes           Yes
# 1     No Internet   No Internet       No Internet  No Internet   No Internet
# 2             Yes           Yes                No           No            No
# 3             Yes           Yes               Yes           No           Yes
# 4              No            No                No           No            No
#
#   streaming_movies multiple_lines
# 0               No   No Telephony
# 1      No Internet             No
# 2               No             No
# 3              Yes             No
# 4               No             No
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          7043 non-null   object
#  1   begin_date           7043 non-null   datetime64[ns]
#  2   end_date             7043 non-null   datetime64[ns]
#  3   type                 7043 non-null   object
#  4   paperless_billing    7043 non-null   object
#  5   payment_method       7043 non-null   object
#  6   monthly_charges      7043 non-null   float64
#  7   total_charges        7043 non-null   float64
#  8   contract_terminated  7043 non-null   int64
#  9   gender               7043 non-null   object
#  10  senior_citizen       7043 non-null   int64
#  11  partner              7043 non-null   object
#  12  dependents           7043 non-null   object
#  13  internet_service     7043 non-null   object
#  14  online_security      7043 non-null   object
#  15  online_backup        7043 non-null   object
#  16  device_protection    7043 non-null   object
#  17  tech_support         7043 non-null   object
#  18  streaming_t_v        7043 non-null   object
#  19  streaming_movies     7043 non-null   object
#  20  multiple_lines       7043 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# Заменим тип данных в колонках 'online_security', 'online_backup', 'device_protection', 'tech_support',
# 'streaming_t_v', 'streaming_movies', 'multiple_lines' на int

# %% [markdown]
# Проверим данные на явные дубли

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          7043 non-null   object
#  1   begin_date           7043 non-null   datetime64[ns]
#  2   end_date             7043 non-null   datetime64[ns]
#  3   type                 7043 non-null   object
#  4   paperless_billing    7043 non-null   object
#  5   payment_method       7043 non-null   object
#  6   monthly_charges      7043 non-null   float64
#  7   total_charges        7043 non-null   float64
#  8   contract_terminated  7043 non-null   int64
#  9   gender               7043 non-null   object
#  10  senior_citizen       7043 non-null   int64
#  11  partner              7043 non-null   object
#  12  dependents           7043 non-null   object
#  13  internet_service     7043 non-null   object
#  14  online_security      7043 non-null   object
#  15  online_backup        7043 non-null   object
#  16  device_protection    7043 non-null   object
#  17  tech_support         7043 non-null   object
#  18  streaming_t_v        7043 non-null   object
#  19  streaming_movies     7043 non-null   object
#  20  multiple_lines       7043 non-null   object
# dtypes: datetime64[ns](2), float64(2), int64(2), object(15)
# memory usage: 1.2+ MB

# %%
data.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  4472-LVYGI 2020-02-01 2020-02-01        Two year               Yes
# 1  3115-CZMZD 2020-02-01 2020-02-01        Two year                No
# 2  3668-QPYBK 2018-08-09 2019-12-01  Month-to-month               Yes
# 3  5709-LVOEQ 2020-02-01 2020-02-01        Two year                No
# 4  9237-HQITU 2019-01-26 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  \
# 0  Bank transfer (automatic)            52.55           0.00
# 1               Mailed check            20.25           0.00
# 2               Mailed check            53.85         108.15
# 3               Mailed check            80.85           0.00
# 4           Electronic check            70.70         151.65
#
#    contract_terminated  gender  ...  partner dependents internet_service  \
# 0                    0  Female  ...      Yes        Yes              DSL
# 1                    0    Male  ...       No        Yes      No Internet
# 2                    1    Male  ...       No         No              DSL
# 3                    0  Female  ...      Yes        Yes              DSL
# 4                    1  Female  ...       No         No      Fiber optic
#
#   online_security online_backup device_protection tech_support streaming_t_v  \
# 0             Yes            No               Yes          Yes           Yes
# 1     No Internet   No Internet       No Internet  No Internet   No Internet
# 2             Yes           Yes                No           No            No
# 3             Yes           Yes               Yes           No           Yes
# 4              No            No                No           No            No
#
#   streaming_movies multiple_lines
# 0               No   No Telephony
# 1      No Internet             No
# 2               No             No
# 3              Yes             No
# 4               No             No
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Генерация новых признаков

# %% [markdown]
# Попробуйте сгенерировать новые признаки, которые могут пригодиться при обучении. Например, рассчитайте длительность контракта абонента.

# %% [markdown]
# Добавим новый признак в датасет "Длительность контракта пользователя". Для этого подсчитаем разницу между концом договора и началом договора ('end_date' и 'begin_date'), сохраним полученные данные в днях и добавим в новую колонку 'contract_duration'.

# %%
# Извлечение длительности контракта в днях
data['contract_duration'] = (data['end_date'] - data['begin_date']).dt.days
data.head()
# Out:
#   customer_id begin_date   end_date            type paperless_billing  \
# 0  4472-LVYGI 2020-02-01 2020-02-01        Two year               Yes
# 1  3115-CZMZD 2020-02-01 2020-02-01        Two year                No
# 2  3668-QPYBK 2018-08-09 2019-12-01  Month-to-month               Yes
# 3  5709-LVOEQ 2020-02-01 2020-02-01        Two year                No
# 4  9237-HQITU 2019-01-26 2019-11-01  Month-to-month               Yes
#
#               payment_method  monthly_charges  total_charges  \
# 0  Bank transfer (automatic)            52.55           0.00
# 1               Mailed check            20.25           0.00
# 2               Mailed check            53.85         108.15
# 3               Mailed check            80.85           0.00
# 4           Electronic check            70.70         151.65
#
#    contract_terminated  gender  ...  dependents internet_service  \
# 0                    0  Female  ...         Yes              DSL
# 1                    0    Male  ...         Yes      No Internet
# 2                    1    Male  ...          No              DSL
# 3                    0  Female  ...         Yes              DSL
# 4                    1  Female  ...          No      Fiber optic
#
#   online_security online_backup device_protection tech_support streaming_t_v  \
# 0             Yes            No               Yes          Yes           Yes
# 1     No Internet   No Internet       No Internet  No Internet   No Internet
# 2             Yes           Yes                No           No            No
# 3             Yes           Yes               Yes           No           Yes
# 4              No            No                No           No            No
#
#   streaming_movies multiple_lines contract_duration
# 0               No   No Telephony                 0
# 1      No Internet             No                 0
# 2               No             No               479
# 3              Yes             No                 0
# 4               No             No               279
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer_id          7043 non-null   object
#  1   begin_date           7043 non-null   datetime64[ns]
#  2   end_date             7043 non-null   datetime64[ns]
#  3   type                 7043 non-null   object
#  4   paperless_billing    7043 non-null   object
#  5   payment_method       7043 non-null   object
#  6   monthly_charges      7043 non-null   float64
#  7   total_charges        7043 non-null   float64
#  8   contract_terminated  7043 non-null   int64
#  9   gender               7043 non-null   object
#  10  senior_citizen       7043 non-null   int64
#  11  partner              7043 non-null   object
#  12  dependents           7043 non-null   object
#  13  internet_service     7043 non-null   object
#  14  online_security      7043 non-null   object
#  15  online_backup        7043 non-null   object
#  16  device_protection    7043 non-null   object
#  17  tech_support         7043 non-null   object
#  18  streaming_t_v        7043 non-null   object
#  19  streaming_movies     7043 non-null   object
#  20  multiple_lines       7043 non-null   object
#  21  contract_duration    7043 non-null   int64
# dtypes: datetime64[ns](2), float64(2), int64(3), object(15)
# memory usage: 1.2+ MB

# %% [markdown]
# Теперь в датасете 22 колонки.

# %% [markdown]
# ## Исследовательский анализ объединенной таблицы

# %% [markdown]
# Проведите исследовательский анализ данных объединённой таблицы, при необходимости заполните пропуски и визуализируйте распределение каждого признака.

# %% [markdown]
# Снова построим столбчатые графики для категориальных значений (в том числе и для бинарных). Теперь графики будут отражать значения и для пропущенных значений.

# %%
# Список колонок для построения графиков
columns_to_plot = ['type', 'paperless_billing', 'payment_method', 'gender', 'senior_citizen',
                  'partner', 'dependents', 'internet_service', 'online_security', 'online_backup',
                  'device_protection', 'tech_support', 'streaming_t_v',
                  'streaming_movies', 'multiple_lines', 'contract_terminated']
titles = ['type', 'paperless_billing', 'payment_method', 'gender', 'senior_citizen',
                  'partner', 'dependents', 'internet_service', 'online_security', 'online_backup',
                  'device_protection', 'tech_support', 'streaming_t_v',
                  'streaming_movies', 'multiple_lines', 'contract_terminated']
colors = ['skyblue', 'lightgreen', 'salmon', 'orchid', 'lightblue', 'lime', 'coral', 'gold',
          'lightpink', 'lightgray', 'aquamarine', 'lightcoral', 'lightcyan', 'lightyellow', 'blue', 'green']

# Настройка фигуры и подграфиков
fig, axes = plt.subplots(4, 4, figsize=(20, 20))

# Цикл для создания столбчатых диаграмм
for ax, column, title, color in zip(axes.flatten(), columns_to_plot, titles, colors):
    data[column].value_counts().plot(kind='bar', ax=ax, color=color)
    ax.set_title(title)
    ax.set_xlabel(column)
    ax.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Распределение значений осталось прежним, но теперь мы видим и количество пользователей, у которых не подключены интернет или телефония.
#
# Целевой признак 'contract_terminated' не сбалансирован. Большинство клиентов (более 5000) не разорвали договора, менее 2000 клиентов - разорвали.
#
# Для числовых значений построим гистограммы.

# %%
col = ['begin_date', 'end_date', 'monthly_charges', 'total_charges', 'contract_duration']

axes = data[col].hist(bins=50, figsize=(15, 15))

for ax in axes.flatten():
    ax.set_ylabel("Frequency", labelpad=20, weight='bold', size=12)

#Поворот меток по оси X под углом 45 градусов
for ax in axes.flatten():
    plt.sca(ax)
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
num_col = ['monthly_charges', 'total_charges', 'contract_duration']
data[num_col].describe().T
# Out:
#                     count         mean          std    min     25%      50%  \
# monthly_charges    7043.0    64.761692    30.090047  18.25   35.50    70.35
# total_charges      7043.0  2279.734304  2266.794470   0.00  398.55  1394.55
# contract_duration  7043.0   297.378674    83.868181   0.00  242.00   298.00
#
#                        75%      max
# monthly_charges      89.85   118.75
# total_charges      3786.60  8684.80
# contract_duration   351.00   583.00

# %% [markdown]
# Добавили новый признак - 'contract_duration' (длительность контракта в днях). В среднем договор длится около 297 дней.
# Min  - 0 дней (совсем новые пользователи, которые подключились в день выгрузки базы), max - 583 дня.

# %% [markdown]
# Визуализирем соотношение ушедших и оставшихся клиентов для каждого признака.

# %%
# Список колонок для построения графиков
columns_to_plot = [
    'end_date', 'type', 'paperless_billing', 'payment_method',
    'gender', 'senior_citizen', 'partner',
    'dependents', 'internet_service', 'online_security', 'online_backup',
    'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies',
    'multiple_lines'
]

# Настройка фигуры и подграфиков
fig, axes = plt.subplots(8, 2, figsize=(50, 45))
axes = axes.flatten()

# Цикл для создания столбчатых диаграмм
for ax, column in zip(axes, columns_to_plot):
    sns.countplot(x=column, hue='contract_terminated', data=data, ax=ax)
    ax.set_title(f'Соотношение оставшихся и ушедших клиентов по {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Количество')

# Удаление пустых подграфиков
for ax in axes[len(columns_to_plot):]:
    fig.delaxes(ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# * Видим даты, когда клиенты закрывали договора 'end_date', они все приходятся на 2019 г: 2019-12-01, 2019-11-01, 2019-10-01.
#
# * Примерно одинаковое количество мужчин и женщин закрывало договора. Гендерный признак 'gender' в нашем случае не коррелирует с целевым признаком.
#
# * Довольно высокая вероятность разрыва договоров среди пенсионеров 'senior_citizen' и холостых клиентов 'partner' без детей 'dependents'.
#
# * Чаще всего разрывают договор те, кто пользуется помесячной оплатой 'type', у кого есть электронный расчётный лист - 'paperless_billing' и кто платит електронными чеками 'payment_method'.
#
# * Большое количество пользователей, разрывающих договор среди тех у кого подключены телефоны к нескольким линиям одновременно 'multiple_lines' и у кого не подключены.
#
# * Большое количество пользователей, разрывающих договор и среди тех у кого подключены стриминговое телевидение 'streaming_t_v' и каталог фильмов 'streaming_movies' и у кого не подключены.
#
# * Хоть большинство пользователей предпочитают подключение интернета через DSL, однако чаще закрывают договора клиенты, пользовавшиеся fiber optic ('internet_service').
#
# * Чаще разрывают договора те клиенты, которые не пользовались техподдержкой 'tech_support', не подключали опцию блокировки опасных сайтов 'online_security', не подключали антивирус 'device_protection' и не подключали облачное хранилище файлов для резервного копирования данны 'online_backup'.

# %%
# Список колонок для построения графиков
columns_to_plot = ['begin_date', 'monthly_charges', 'total_charges', 'contract_duration']

# Настройка фигуры и подграфиков
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.flatten()

# Цикл для создания графиков
for ax, column in zip(axes, columns_to_plot):
    if column == 'begin_date':
        sns.scatterplot(x=column, y='contract_terminated', data=data, ax=ax)
    else:
        sns.boxplot(x='contract_terminated', y=column, data=data, ax=ax)
    ax.set_title(f'Соотношение оставшихся и ушедших клиентов по {column}')
    ax.set_xlabel(column)
    ax.set_ylabel('Значение')

plt.tight_layout()
plt.show()

# %% [markdown]
# * Сложно установить связь между датой начала заключения договора 'begin_date' и фактом его разрыва. Можно лишь отметить, что те, кто заключал договор до 2018-07 разорвали договор. И те кто заключал договор в период  2019-10 - 2020-01 не разорвали договор, но возможно, потому что прошло еще не так много времени.
#
# * Ежемесячные траты 'monthly_charges' у тех, кто не разорвал договор ниже, и находятся в диапазоне (нижний и верхний квартиль) - 25-90 с медианой 65.
# В то время, как у тех, кто разрывал контракт ежемесячные траты были выше:  верхний и нижний квартиль 55-95 с медианой 80.
#
# * Однако общие траты 'total_charges' у тех кто не разорвал договр а выше, чем у тех, кто разорвал. Нижний и верхний квартиль у таких клиентов в диапазоне 500-4250 с медианой 1900.
# У тех, кто разрывал договор диапазон 100-2100 с медианой 250.
#
# * Длительность контракта 'contract_duration' (в днях) примерно одинаковая и для тех кто разорвал договор и для тех, кто нет. Нижний и верхний квартиль 250-350 дней, медианное значение - 300. дней

# %% [markdown]
# Выберите признаки, которые будете использовать для обучения, учитывайте особенности данных и выбранных моделей. Перед вами не стоит задача временных рядов, поэтому не стоит использовать даты как входные признаки модели.
#
# Если вы сгенерируете новый признак «Длительность контракта абонента», то не используйте его одновременно с любыми другими производными признака BeginDate — например с годом заключения договора. Это приведёт к утечке целевого признака.

# %% [markdown]
# Проведем корреляционный анализ.

# %%
# Создание копии датафрейма и удаление колонки customer_id
data_copy = data.copy()
data_copy.drop(columns=['customer_id'], inplace=True)

# Указание интервальных колонок
interval_columns = ['monthly_charges', 'total_charges', 'contract_duration']

# Расчет корреляционной матрицы phik с указанием интервальных колонок
phik_overview = data_copy.phik_matrix(interval_cols=interval_columns)
phik_overview = phik_overview.round(2)

# Построение корреляционной матрицы
plot_correlation_matrix(phik_overview.values,
                        x_labels=phik_overview.columns,
                        y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map="Greens",
                        title="Phik Correlation Matrix",
                        fontsize_factor=1,
                        figsize=(16, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# * Наблюдается сильная корреляция между категориальными/бинарными признаками, относящимися к интернет услугам: 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies', 'internet_service'.
#
# * Также есть сильная корреляция между количественным признаком 'monthly_charges' и бинарными: 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies', 'internet_service'
#
# * А также между 'contract_duration' и begin_date и между 'contract_terminated' и end_date.
#
# Удалим 'monthly_charges' так как это числовой признак и он сильно коррелирует с другими.
#
# Для бинарных или номинальных данных (категории) использование корреляционных методов, предназначенных для количественных данных, может привести к некорректным или малоинформативным результатам.
# Однако удалим 'gender', 'contract_duration', 'multiple_lines', 'streaming_movies', 'streaming_t_v' - так как мы выяснили при анализе данных, что эти признаки не влияют на то, разорвал ли клмент договор или нет - при наличии этих признаков, пропорция 0/1 примерно одинаковая.
#
# Удалим также 'customer_id', 'begin_date', 'end_date'.

# %%
data = data.drop(['customer_id', 'begin_date', 'end_date', 'monthly_charges', 'gender', 'contract_duration',
                 'multiple_lines', 'streaming_movies', 'streaming_t_v'], axis=1)
data.head()
# Out:
#              type paperless_billing             payment_method  total_charges  \
# 0        Two year               Yes  Bank transfer (automatic)           0.00
# 1        Two year                No               Mailed check           0.00
# 2  Month-to-month               Yes               Mailed check         108.15
# 3        Two year                No               Mailed check           0.00
# 4  Month-to-month               Yes           Electronic check         151.65
#
#    contract_terminated  senior_citizen partner dependents internet_service  \
# 0                    0               0     Yes        Yes              DSL
# 1                    0               0      No        Yes      No Internet
# 2                    1               0      No         No              DSL
# 3                    0               0     Yes        Yes              DSL
# 4                    1               0      No         No      Fiber optic
#
#   online_security online_backup device_protection tech_support
# 0             Yes            No               Yes          Yes
# 1     No Internet   No Internet       No Internet  No Internet
# 2             Yes           Yes                No           No
# 3             Yes           Yes               Yes           No
# 4              No            No                No           No

# %% [markdown]
# После удаления ненужных колонок проверим датасет еще раз на дубли.

# %%
data.duplicated().sum()
# Out:
# 47

# %%
# Удалим дубликаты
data.drop_duplicates(inplace=True, ignore_index=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6996 entries, 0 to 6995
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   type                 6996 non-null   object
#  1   paperless_billing    6996 non-null   object
#  2   payment_method       6996 non-null   object
#  3   total_charges        6996 non-null   float64
#  4   contract_terminated  6996 non-null   int64
#  5   senior_citizen       6996 non-null   int64
#  6   partner              6996 non-null   object
#  7   dependents           6996 non-null   object
#  8   internet_service     6996 non-null   object
#  9   online_security      6996 non-null   object
#  10  online_backup        6996 non-null   object
#  11  device_protection    6996 non-null   object
#  12  tech_support         6996 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 710.7+ KB

# %%
# Итоговые признаки, которые берем на этап обучения моделей
data.columns
# Out:
# Index(['type', 'paperless_billing', 'payment_method', 'total_charges',
#        'contract_terminated', 'senior_citizen', 'partner', 'dependents',
#        'internet_service', 'online_security', 'online_backup',
#        'device_protection', 'tech_support'],
#       dtype='object')

# %% [markdown]
# Таким образом у нас осталось 13 признаков и 6996 клиентов.
# Эти данные берем для дальнейшего обучения моделей.

# %% [markdown]
# ## Вывод

# %% [markdown]
# На этапе исследовательского анализа и предобработки данных
#
# * **Выгрузили из базы данных 4 таблицы:**
#
#     * contract — информация о договорах;
#     * personal — персональные данные клиентов;
#     * internet — информация об интернет-услугах;
#     * phone — информация об услугах телефонии.
#
# * Проанализировали исходные данные. Проверили данные на наличие пропусков, явных дубликатов, аномалий.
# Изучили распределение признаков.
#
# * Обработали аномалии с учётом особенностей услуг телекоммуникации.
#
# * Исправили типы данных.
#
# * Объединили таблицы по ID клиента.
#
# * Сгенерировали новый признак: длительность контракта абонента в днях - 'contract_duration'.
#
# * Выделили в **целевую переменную** признак EndDate - **'contract terminated'** (разорвал ли клиент договор 0 - нет, 1 - да)
#
# * Провели исследовательский анализ данных объединённой таблицы,  заполнили пропуски и визуализировали распределение каждого признака:
#
#     * У большинства клиентов тип интернет-подключения 'internet_service' - fiber optic.
#     * Большинство клиентов не подключали опцию блокировка опасных сайтов 'online_security'.
#     * Большинство клиентов не подключали опцию - облачное хранилище файлов для резервного копирования данных 'online_backup'
#     * Большинство клиентов не подключали опцию антивирус 'device_protection'
#     * Большинство клиентов не подключали опцию выделенная линия технической поддержки 'tech_support'
#     * Примерно одинаковое количество клиентов пользуются/не пользуются стриминговым телевидением 'streaming_t_v'
#     * Примерно одинаковое количество клиентов пользуются/не пользуются каталогом фильмов 'streaming_movies'
#     * Новый признак - 'contract_duration' (длительность контракта в днях). В среднем договор длится около 297 дней. Min - 0 дней (совсем новые пользователи, которые подключились в день выгрузки базы), max - 583 дня.
#     * Целевой признак 'contract_terminated' не сбалансирован. Большинство клиентов (более 5000) не разорвали договора, менее 2000 клиентов - разорвали.
#
#
# * Визуализировали соотношение ушедших и оставшихся клиентов для каждого признака:
#
#     * Видим даты, когда клиенты закрывали договора 'end_date', они все приходятся на 2019 г: 2019-12-01, 2019-11-01, 2019-10-01.
#
#     * Примерно одинаковое количество мужчин и женщин закрывало договора. Гендерный признак 'gender' в нашем случае не коррелирует с целевым признаком.
#
#     * Довольно высокая вероятность разрыва договоров среди пенсионеров 'senior_citizen' и холостых клиентов 'partner' без детей 'dependents'.
#
#     * Чаще всего разрывают договор те, кто пользуется помесячной оплатой 'type', у кого есть электронный расчётный лист - 'paperless_billing' и кто платит електронными чеками 'payment_method'.
#
#     * Большое количество пользователей, разрывающих договор среди тех у кого подключены телефоны к нескольким линиям одновременно 'multiple_lines' и у кого не подключены.
#
#     * Большое количество пользователей, разрывающих договор и среди тех у кого подключены стриминговое телевидение 'streaming_t_v' и каталог фильмов 'streaming_movies' и у кого не подключены.
#
#     * Хоть большинство пользователей предпочитают подключение интернета через DSL, однако чаще закрывают договора клиенты, пользовавшиеся fiber optic ('internet_service').
#
#     * Чаще разрывают договора те клиенты, которые не пользовались техподдержкой 'tech_support', не подключали опцию блокировки опасных сайтов 'online_security', не подключали антивирус 'device_protection' и не подключали облачное хранилище файлов для резервного копирования данны 'online_backup'.
#
#     * Сложно установить связь между датой начала заключения договора 'begin_date' и фактом его разрыва. Можно лишь отметить, что те, кто заключал договор до 2018-07 разорвали договор. И те кто заключал договор в период 2019-10 - 2020-01 не разорвали договор, но возможно, потому что прошло еще не так много времени.
#
#     * Ежемесячные траты 'monthly_charges' у тех, кто не разорвал договор ниже, и находятся в диапазоне (нижний и верхний квартиль) - 25-90 с медианой 65. В то время, как у тех, кто разрывал контракт ежемесячные траты были выше: верхний и нижний квартиль 55-95 с медианой 80.
#
#     * Однако общие траты 'total_charges' у тех кто не разорвал договр а выше, чем у тех, кто разорвал. Нижний и верхний квартиль у таких клиентов в диапазоне 500-4250 с медианой 1900. У тех, кто разрывал договор диапазон 100-2100 с медианой 250.
#
#     * Длительность контракта 'contract_duration' (в днях) примерно одинаковая и для тех кто разорвал договор и для тех, кто нет. Нижний и верхний квартиль 250-350 дней, медианное значение - 300. дней
#
#
# * Провели корреляционный анализ:
#
#     * Наблюдается сильная корреляция между категориальными/бинарными признаками, относящимися к интернет услугам: 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies', 'internet_service'.
#
#     * Также есть сильная корреляция между количественным признаком 'monthly_charges' и бинарными: 'online_security', 'online_backup', 'device_protection', 'tech_support', 'streaming_t_v', 'streaming_movies', 'internet_service'
#
#     * А также между 'contract_duration' и begin_date и между 'contract_terminated' и end_date.
#
#     Удалять бинарные/категориальные признаки мы не будем. Для бинарных (0/1) или номинальных данных (категории) использование корреляционных методов, предназначенных для количественных данных, может привести к некорректным или малоинформативным результатам.
#
#     * Удалили признаки: 'begin_date', 'end_date', 'monthly_charges', 'customer_id', 'gender'.
#
# Таким образом у нас осталось 13 признаков и 6996 клиентов. Эти данные берем для дальнейшего обучения моделей:
#
# 'type', 'paperless_billing', 'payment_method', 'total_charges', 'contract_terminated', 'senior_citizen', 'partner', 'dependents', 'internet_service', 'online_security', 'online_backup', 'device_protection', 'tech_support'.

# %% [markdown]
# # Подготовка данных к обучению. Обучение моделей

# %% [markdown]
# Подготовьте данные для обучения:
#
# Разделите данные на тренировочную и тестовую выборки (test_size = 0.25).
# Подготовьте выборки для обучения, учитывайте особенности выбранных моделей.
#
# Рассмотрите классы моделей:
# - решающее дерево или случайный лес,
# - бустинги,
# - нейронные сети.
#
# Найдите лучшую модель для прогноза оттока клиентов. Оцените её качество метрикой **ROC-AUC**. Выберите лучшую модель по значению метрики на кросс-валидации.
#
# Подберите значения как минимум двум гиперпараметрам хотя бы для одной модели. Лучше всего использовать методы автоматизированного подбора гиперпараметров: GridSearchCV, RandomizedSearchCV, OptunaSearchCV, Optuna и другие.

# %% [markdown]
# Цель нашего проекта: разработать модель, которая сможет предсказывать, разорвёт ли абонент договор
# Целевая переменная 'contract_terminated' (0 - не разорвет, 1 - разорвет)
#
# Перед нами задача классификации.
#
# Разделим датасет на тренировочную и тестовые выборки.
#
# Обучим модели на тренировочных данных:
#
# * RandomForestClassifier
# * CatBoostClassifier
# * LGBMClassifier

# %%
# Выделим целевой признак
X = data.drop('contract_terminated', axis=1)
y = data['contract_terminated']

# %%
# Выделим категориальные и числовые столбцы для обработки
categorical_cols = ['type', 'payment_method', 'paperless_billing',
                    'senior_citizen', 'partner', 
                    'dependents', 'internet_service', 'online_security',
                    'online_backup', 'device_protection', 'tech_support']

numerical_cols = ['total_charges']

# %% [markdown]
# Разделим модель на обучающую и тестовую выборки (test_size = 0.25).
# Добавим параметр stratify, чтобы отношение данных целевого признака в подвыборках было одинаковым. Это важно, так как наша целевая переменная 'contract_terminated' несбалансирована.

# %%
# разделим модель на обучающую и тестовую выборки
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, stratify=y, random_state=RANDOM_STATE)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (5247, 12) (1749, 12) (5247,) (1749,)

# %% [markdown]
# В нашем исследовании не будем отдельно балансировать тренировочную выборку, так как планируем использовать кросс-валидацию GridSearchCV.
# Дело в том, что для одной и той же модели оценка метрики качества на сбалансированной выборке гораздо выше, чем на несбалансированной. Если обучать объект GridSearchCV на сбалансированной обучающей выборке, в процессе кросс-валидации она будет разделена на несколько фолдов, из которых будут выделены валидационные и обучающие. И эти валидационные фолды тоже будут сбалансироваными. И как следствие, мы получим завышенные метрики и рискуем выбрать не самую лучшую модель и гиперпараметры.
#
# Поэтому лучше отказаться от балансировки.
#
# Обучим выбранные модели на тренировочных данных.
# Оценивать качество моделей будем метрикой **ROC-AUC**.

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### RandomForestClassifier

# %%
# Создадим DataFrame для хранения результатов тестирования моделей
results = pd.DataFrame(columns=['Model', 'ROC-AUC'])

# %%
# Обработка категориальных признаков с помощью OrdinalEncoder
cat_pipeline = Pipeline([
    ('encoder', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

# Обработка числовых данных с помощью StandardScaler
num_pipeline = Pipeline([
    ('scaler', StandardScaler())
])

# %%
# Компоновка обработчиков признаков
col_transf = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, numerical_cols),
    ('cat_pipeline', cat_pipeline, categorical_cols)
], n_jobs=-1)

# Инициализация модели RandomForestClassifier и компоновщика признаков в один конвейер
pipeline_rf = Pipeline([
    ('col_transf', col_transf),
    ('model_rf', RandomForestClassifier(n_jobs=-1, random_state=RANDOM_STATE))
])

# %%
# Задание сетки параметров для подбора гиперпараметров RandomForestClassifier
param_rf = {
    'model_rf__n_estimators': [10, 50, 100],
    'model_rf__max_depth': [None, 3, 5, 8],
    'model_rf__min_samples_leaf': [1, 2, 4]
}

# %%
# Подбор лучших гиперпараметров с помощью GridSearchCV
grid_rf = GridSearchCV(pipeline_rf, param_grid=param_rf, cv=5, scoring='roc_auc', n_jobs=-1)
grid_rf.fit(X_train, y_train)

# Получение лучших параметров и оценки ROC-AUC
best_params_rf = grid_rf.best_params_
score_rf = grid_rf.best_score_

print(f'\nЛучшие параметры RandomForestClassifier: {best_params_rf}')
print(f'Лучшая оценка ROC-AUC: {score_rf}')

# Добавление результатов в общую таблицу результатов
results = pd.concat([results, pd.DataFrame({
    'Model': ['RandomForestClassifier'],
    'ROC-AUC': [score_rf]
})], ignore_index=True)
# Out:
# Лучшие параметры RandomForestClassifier: {'model_rf__max_depth': 5, 'model_rf__min_samples_leaf': 2, 'model_rf__n_estimators': 100}
# Лучшая оценка ROC-AUC: 0.8359938220007461

# %% [markdown]
# ### CatBoostClassifier

# %%
# Получим индексы категориальных признаков
categorical_cols_idx = [X_train.columns.get_loc(col) for col in categorical_cols]

# Создадим модель CatBoostClassifier с указанием индексов категориальных признаков
catboost_model = CatBoostClassifier(cat_features=categorical_cols_idx, random_state=RANDOM_STATE)

# %%
param_catboost = {
    'learning_rate': [0.01, 0.1, 0.3],
    'depth': [4, 6, 8, 10],
    'iterations': [50, 100, 150, 200],
    'l2_leaf_reg': [1, 3, 5, 8]
}

grid_catboost = GridSearchCV(catboost_model, param_grid=param_catboost, cv=5,
                       n_jobs=-1, scoring='roc_auc')

grid_catboost.fit(X_train, y_train)

best_params_catboost = grid_catboost.best_params_
score_catboost = grid_catboost.best_score_

print(f'\nЛучшие параметры CatBoostClassifier: {best_params_catboost}')
print(f'Лучшая оценка ROC-AUC: {score_catboost}')

results = pd.concat([results, pd.DataFrame({
    'Model': ['CatBoostClassifier'],
    'ROC-AUC': [score_catboost]
})], ignore_index=True)
# Out:
# 0:	learn: 0.6902296	total: 50ms	remaining: 2.45s
# 1:	learn: 0.6872218	total: 52.7ms	remaining: 1.26s
# 2:	learn: 0.6841827	total: 54.6ms	remaining: 856ms
# 3:	learn: 0.6813036	total: 56.8ms	remaining: 653ms
# 4:	learn: 0.6787091	total: 58.8ms	remaining: 529ms
# 5:	learn: 0.6758363	total: 60.8ms	remaining: 446ms
# 6:	learn: 0.6732144	total: 63.3ms	remaining: 389ms
# 7:	learn: 0.6705909	total: 66.2ms	remaining: 348ms
# 8:	learn: 0.6678878	total: 69.2ms	remaining: 315ms
# 9:	learn: 0.6652470	total: 71.6ms	remaining: 286ms
# 10:	learn: 0.6626325	total: 73.3ms	remaining: 260ms
# 11:	learn: 0.6602190	total: 75.1ms	remaining: 238ms
# 12:	learn: 0.6579228	total: 76.9ms	remaining: 219ms
# 13:	learn: 0.6555537	total: 78.6ms	remaining: 202ms
# 14:	learn: 0.6532397	total: 80.5ms	remaining: 188ms
# 15:	learn: 0.6509225	total: 82.4ms	remaining: 175ms
# 16:	learn: 0.6487367	total: 84.3ms	remaining: 164ms
# 17:	learn: 0.6464196	total: 86.2ms	remaining: 153ms
# 18:	learn: 0.6441911	total: 88ms	remaining: 144ms
# 19:	learn: 0.6423084	total: 89.8ms	remaining: 135ms
# 20:	learn: 0.6400769	total: 91.6ms	remaining: 126ms
# 21:	learn: 0.6379471	total: 93.7ms	remaining: 119ms
# 22:	learn: 0.6358498	total: 95.5ms	remaining: 112ms
# 23:	learn: 0.6337489	total: 97.3ms	remaining: 105ms
# 24:	learn: 0.6317296	total: 99.2ms	remaining: 99.2ms
# 25:	learn: 0.6298579	total: 101ms	remaining: 93.2ms
# 26:	learn: 0.6274882	total: 102ms	remaining: 87.2ms
# 27:	learn: 0.6251328	total: 104ms	remaining: 81.8ms
# 28:	learn: 0.6227478	total: 106ms	remaining: 76.6ms
# 29:	learn: 0.6204672	total: 108ms	remaining: 71.8ms
# 30:	learn: 0.6182204	total: 109ms	remaining: 66.9ms
# 31:	learn: 0.6160121	total: 111ms	remaining: 62.6ms
# 32:	learn: 0.6137376	total: 113ms	remaining: 58.3ms
# 33:	learn: 0.6115462	total: 115ms	remaining: 54.1ms
# 34:	learn: 0.6094511	total: 117ms	remaining: 50.1ms
# 35:	learn: 0.6072885	total: 119ms	remaining: 46.1ms
# 36:	learn: 0.6052568	total: 121ms	remaining: 42.4ms
# 37:	learn: 0.6032207	total: 122ms	remaining: 38.7ms
# 38:	learn: 0.6011907	total: 124ms	remaining: 35.1ms
# 39:	learn: 0.5991642	total: 126ms	remaining: 31.5ms
# 40:	learn: 0.5972191	total: 128ms	remaining: 28.1ms
# 41:	learn: 0.5953184	total: 130ms	remaining: 24.8ms
# 42:	learn: 0.5934616	total: 132ms	remaining: 21.5ms
# 43:	learn: 0.5916999	total: 133ms	remaining: 18.1ms
# 44:	learn: 0.5898362	total: 135ms	remaining: 15ms
# 45:	learn: 0.5879872	total: 137ms	remaining: 11.9ms
# 46:	learn: 0.5861878	total: 139ms	remaining: 8.87ms
# 47:	learn: 0.5845411	total: 140ms	remaining: 5.84ms
# 48:	learn: 0.5828118	total: 142ms	remaining: 2.9ms
# 49:	learn: 0.5811910	total: 144ms	remaining: 0us
# 0:	learn: 0.6901997	total: 2.27ms	remaining: 111ms
# 1:	learn: 0.6871186	total: 4.66ms	remaining: 112ms
# 2:	learn: 0.6840623	total: 6.66ms	remaining: 104ms
# 3:	learn: 0.6810505	total: 8.68ms	remaining: 99.8ms
# 4:	learn: 0.6784168	total: 10.6ms	remaining: 95.1ms
# 5:	learn: 0.6755378	total: 12.4ms	remaining: 90.8ms
# 6:	learn: 0.6728791	total: 14.7ms	remaining: 90.5ms
# 7:	learn: 0.6702223	total: 16.6ms	remaining: 87ms
# 8:	learn: 0.6676159	total: 18.3ms	remaining: 83.5ms
# 9:	learn: 0.6649139	total: 20.2ms	remaining: 80.7ms
# 10:	learn: 0.6623059	total: 22ms	remaining: 78.1ms
# 11:	learn: 0.6598686	total: 24ms	remaining: 76ms
# 12:	learn: 0.6575283	total: 26.1ms	remaining: 74.2ms
# 13:	learn: 0.6551146	total: 27.8ms	remaining: 71.6ms
# 14:	learn: 0.6527473	total: 29.8ms	remaining: 69.4ms
# 15:	learn: 0.6503137	total: 31.6ms	remaining: 67.2ms
# 16:	learn: 0.6480965	total: 33.7ms	remaining: 65.5ms
# 17:	learn: 0.6457814	total: 35.7ms	remaining: 63.5ms
# 18:	learn: 0.6434776	total: 37.6ms	remaining: 61.4ms
# 19:	learn: 0.6415991	total: 39.6ms	remaining: 59.4ms
# 20:	learn: 0.6396736	total: 41.2ms	remaining: 56.9ms
# 21:	learn: 0.6375099	total: 43.1ms	remaining: 54.9ms
# 22:	learn: 0.6354265	total: 44.8ms	remaining: 52.6ms
# 23:	learn: 0.6334074	total: 46.5ms	remaining: 50.4ms
# 24:	learn: 0.6313758	total: 48.5ms	remaining: 48.5ms
# 25:	learn: 0.6293649	total: 50.5ms	remaining: 46.6ms
# 26:	learn: 0.6274171	total: 52.5ms	remaining: 44.7ms
# 27:	learn: 0.6254351	total: 54.4ms	remaining: 42.7ms
# 28:	learn: 0.6235269	total: 56.3ms	remaining: 40.8ms
# 29:	learn: 0.6212607	total: 57.6ms	remaining: 38.4ms
# 30:	learn: 0.6190508	total: 59.1ms	remaining: 36.2ms
# 31:	learn: 0.6168633	total: 60.4ms	remaining: 34ms
# 32:	learn: 0.6146118	total: 62.2ms	remaining: 32ms
# 33:	learn: 0.6123940	total: 64.2ms	remaining: 30.2ms
# 34:	learn: 0.6103161	total: 65.9ms	remaining: 28.2ms
# 35:	learn: 0.6081281	total: 67.9ms	remaining: 26.4ms
# 36:	learn: 0.6060157	total: 69.8ms	remaining: 24.5ms
# 37:	learn: 0.6038791	total: 71.7ms	remaining: 22.6ms
# 38:	learn: 0.6017841	total: 73.7ms	remaining: 20.8ms
# 39:	learn: 0.5997380	total: 75.6ms	remaining: 18.9ms
# 40:	learn: 0.5978500	total: 76.9ms	remaining: 16.9ms
# 41:	learn: 0.5958878	total: 78.8ms	remaining: 15ms
# 42:	learn: 0.5939965	total: 80.7ms	remaining: 13.1ms
# 43:	learn: 0.5921535	total: 82.6ms	remaining: 11.3ms
# 44:	learn: 0.5902408	total: 84.6ms	remaining: 9.4ms
# 45:	learn: 0.5884362	total: 86.6ms	remaining: 7.53ms
# 46:	learn: 0.5866853	total: 88.3ms	remaining: 5.64ms
# 47:	learn: 0.5849438	total: 90.2ms	remaining: 3.76ms
# 48:	learn: 0.5831935	total: 92ms	remaining: 1.88ms
# 49:	learn: 0.5815138	total: 94ms	remaining: 0us
# 0:	learn: 0.6901564	total: 2.51ms	remaining: 123ms
# 1:	learn: 0.6870210	total: 5.11ms	remaining: 123ms
# 2:	learn: 0.6841525	total: 7.06ms	remaining: 111ms
# 3:	learn: 0.6811224	total: 9.27ms	remaining: 107ms
# 4:	learn: 0.6785117	total: 11.1ms	remaining: 100ms
# 5:	learn: 0.6758442	total: 12.9ms	remaining: 94.7ms
# 6:	learn: 0.6732422	total: 14.8ms	remaining: 91.1ms
# 7:	learn: 0.6704553	total: 16.6ms	remaining: 87.1ms
# 8:	learn: 0.6679483	total: 18.4ms	remaining: 83.9ms
# 9:	learn: 0.6654919	total: 20.2ms	remaining: 80.7ms
# 10:	learn: 0.6629419	total: 22.1ms	remaining: 78.3ms
# 11:	learn: 0.6604074	total: 23.9ms	remaining: 75.7ms
# 12:	learn: 0.6579632	total: 25.8ms	remaining: 73.3ms
# 13:	learn: 0.6555115	total: 27.6ms	remaining: 70.9ms
# 14:	learn: 0.6531121	total: 29.4ms	remaining: 68.5ms
# 15:	learn: 0.6507319	total: 31.2ms	remaining: 66.3ms
# 16:	learn: 0.6484033	total: 33.2ms	remaining: 64.4ms
# 17:	learn: 0.6461418	total: 35.2ms	remaining: 62.6ms
# 18:	learn: 0.6439164	total: 37ms	remaining: 60.3ms
# 19:	learn: 0.6416681	total: 38.9ms	remaining: 58.4ms
# 20:	learn: 0.6394950	total: 41ms	remaining: 56.6ms
# 21:	learn: 0.6374377	total: 42.9ms	remaining: 54.6ms
# 22:	learn: 0.6353049	total: 44.7ms	remaining: 52.5ms
# 23:	learn: 0.6334016	total: 46.7ms	remaining: 50.6ms
# 24:	learn: 0.6314432	total: 48.6ms	remaining: 48.6ms
# 25:	learn: 0.6296092	total: 50.5ms	remaining: 46.6ms
# 26:	learn: 0.6270921	total: 52.5ms	remaining: 44.7ms
# 27:	learn: 0.6247535	total: 54.3ms	remaining: 42.7ms
# 28:	learn: 0.6222869	total: 56.3ms	remaining: 40.8ms
# 29:	learn: 0.6198803	total: 58.1ms	remaining: 38.8ms
# 30:	learn: 0.6175650	total: 60ms	remaining: 36.7ms
# 31:	learn: 0.6153512	total: 61.7ms	remaining: 34.7ms
# 32:	learn: 0.6130974	total: 63.6ms	remaining: 32.8ms
# 33:	learn: 0.6109446	total: 65.4ms	remaining: 30.8ms
# 34:	learn: 0.6087996	total: 67.3ms	remaining: 28.8ms
# 35:	learn: 0.6067115	total: 69.2ms	remaining: 26.9ms
# 36:	learn: 0.6045441	total: 70.8ms	remaining: 24.9ms
# 37:	learn: 0.6024758	total: 72.6ms	remaining: 22.9ms
# 38:	learn: 0.6004896	total: 74.5ms	remaining: 21ms
# 39:	learn: 0.5985570	total: 75.7ms	remaining: 18.9ms
# 40:	learn: 0.5965365	total: 77.6ms	remaining: 17ms
# 41:	learn: 0.5945663	total: 79.7ms	remaining: 15.2ms
# 42:	learn: 0.5926561	total: 81.5ms	remaining: 13.3ms
# 43:	learn: 0.5908413	total: 83.4ms	remaining: 11.4ms
# 44:	learn: 0.5890437	total: 85.1ms	remaining: 9.45ms
# 45:	learn: 0.5871409	total: 86.9ms	remaining: 7.56ms
# 46:	learn: 0.5854021	total: 88.6ms	remaining: 5.66ms
# 47:	learn: 0.5836842	total: 90.5ms	remaining: 3.77ms
# 48:	learn: 0.5819636	total: 92.3ms	remaining: 1.88ms
# 49:	learn: 0.5802163	total: 94.1ms	remaining: 0us
# 0:	learn: 0.6901333	total: 2.63ms	remaining: 129ms
# 1:	learn: 0.6869389	total: 5.1ms	remaining: 122ms
# 2:	learn: 0.6840439	total: 7.1ms	remaining: 111ms
# 3:	learn: 0.6809776	total: 9.36ms	remaining: 108ms
# 4:	learn: 0.6779844	total: 11.2ms	remaining: 100ms
# 5:	learn: 0.6752770	total: 13.1ms	remaining: 96.2ms
# 6:	learn: 0.6725977	total: 15ms	remaining: 92.3ms
# 7:	learn: 0.6697717	total: 16.9ms	remaining: 88.8ms
# 8:	learn: 0.6672522	total: 18.8ms	remaining: 85.8ms
# 9:	learn: 0.6647204	total: 20.7ms	remaining: 82.9ms
# 10:	learn: 0.6621336	total: 22.7ms	remaining: 80.4ms
# 11:	learn: 0.6595830	total: 24.5ms	remaining: 77.7ms
# 12:	learn: 0.6571414	total: 26.4ms	remaining: 75.1ms
# 13:	learn: 0.6546925	total: 28.1ms	remaining: 72.2ms
# 14:	learn: 0.6522191	total: 30ms	remaining: 69.9ms
# 15:	learn: 0.6498159	total: 31.8ms	remaining: 67.6ms
# 16:	learn: 0.6474423	total: 33.7ms	remaining: 65.4ms
# 17:	learn: 0.6451741	total: 35.6ms	remaining: 63.3ms
# 18:	learn: 0.6429648	total: 37.5ms	remaining: 61.1ms
# 19:	learn: 0.6406817	total: 39.4ms	remaining: 59.1ms
# 20:	learn: 0.6384786	total: 41.3ms	remaining: 57ms
# 21:	learn: 0.6363795	total: 43.2ms	remaining: 54.9ms
# 22:	learn: 0.6342149	total: 45ms	remaining: 52.8ms
# 23:	learn: 0.6321335	total: 46.9ms	remaining: 50.9ms
# 24:	learn: 0.6301511	total: 48.7ms	remaining: 48.7ms
# 25:	learn: 0.6283272	total: 50.6ms	remaining: 46.7ms
# 26:	learn: 0.6258860	total: 52.6ms	remaining: 44.8ms
# 27:	learn: 0.6234759	total: 54.4ms	remaining: 42.8ms
# 28:	learn: 0.6210178	total: 56.4ms	remaining: 40.8ms
# 29:	learn: 0.6186101	total: 58.1ms	remaining: 38.7ms
# 30:	learn: 0.6162870	total: 60ms	remaining: 36.8ms
# 31:	learn: 0.6140954	total: 61.8ms	remaining: 34.7ms
# 32:	learn: 0.6118803	total: 63.6ms	remaining: 32.7ms
# 33:	learn: 0.6097114	total: 65.3ms	remaining: 30.7ms
# 34:	learn: 0.6075407	total: 67.2ms	remaining: 28.8ms
# 35:	learn: 0.6054577	total: 69.1ms	remaining: 26.9ms
# 36:	learn: 0.6033480	total: 71ms	remaining: 25ms
# 37:	learn: 0.6012862	total: 72.9ms	remaining: 23ms
# 38:	learn: 0.5993004	total: 74.8ms	remaining: 21.1ms
# 39:	learn: 0.5973740	total: 76ms	remaining: 19ms
# 40:	learn: 0.5953590	total: 78ms	remaining: 17.1ms
# 41:	learn: 0.5935680	total: 79.3ms	remaining: 15.1ms
# 42:	learn: 0.5917466	total: 81.3ms	remaining: 13.2ms
# 43:	learn: 0.5899560	total: 82.6ms	remaining: 11.3ms
# 44:	learn: 0.5881524	total: 84.5ms	remaining: 9.39ms
# 45:	learn: 0.5863050	total: 86.6ms	remaining: 7.53ms
# 46:	learn: 0.5845779	total: 88.6ms	remaining: 5.65ms
# 47:	learn: 0.5828115	total: 90.6ms	remaining: 3.77ms
# 48:	learn: 0.5810896	total: 93.8ms	remaining: 1.91ms
# 49:	learn: 0.5794386	total: 96.8ms	remaining: 0us
# 0:	learn: 0.6901290	total: 2.34ms	remaining: 115ms
# 1:	learn: 0.6869298	total: 4.61ms	remaining: 111ms
# 2:	learn: 0.6840299	total: 6.47ms	remaining: 101ms
# 3:	learn: 0.6809294	total: 8.57ms	remaining: 98.5ms
# 4:	learn: 0.6778921	total: 10.4ms	remaining: 94ms
# 5:	learn: 0.6751514	total: 12.3ms	remaining: 90.2ms
# 6:	learn: 0.6724828	total: 14.2ms	remaining: 87.5ms
# 7:	learn: 0.6696187	total: 15.9ms	remaining: 83.5ms
# 8:	learn: 0.6668568	total: 17.5ms	remaining: 79.8ms
# 9:	learn: 0.6643328	total: 19.5ms	remaining: 78ms
# 10:	learn: 0.6616943	total: 21.5ms	remaining: 76.2ms
# 11:	learn: 0.6590889	total: 23.2ms	remaining: 73.6ms
# 12:	learn: 0.6566265	total: 25ms	remaining: 71.1ms
# 13:	learn: 0.6541499	total: 26.9ms	remaining: 69.1ms
# 14:	learn: 0.6516739	total: 28.7ms	remaining: 67.1ms
# 15:	learn: 0.6491979	total: 30.7ms	remaining: 65.2ms
# 16:	learn: 0.6468786	total: 32.5ms	remaining: 63.1ms
# 17:	learn: 0.6445676	total: 34.2ms	remaining: 60.8ms
# 18:	learn: 0.6423462	total: 36.1ms	remaining: 58.9ms
# 19:	learn: 0.6400488	total: 37.8ms	remaining: 56.7ms
# 20:	learn: 0.6378158	total: 39.6ms	remaining: 54.7ms
# 21:	learn: 0.6356816	total: 41.4ms	remaining: 52.7ms
# 22:	learn: 0.6335034	total: 43.3ms	remaining: 50.9ms
# 23:	learn: 0.6313763	total: 45.2ms	remaining: 49ms
# 24:	learn: 0.6293984	total: 47.2ms	remaining: 47.2ms
# 25:	learn: 0.6275668	total: 49ms	remaining: 45.2ms
# 26:	learn: 0.6250841	total: 50.8ms	remaining: 43.3ms
# 27:	learn: 0.6227126	total: 52.8ms	remaining: 41.5ms
# 28:	learn: 0.6202600	total: 54.7ms	remaining: 39.6ms
# 29:	learn: 0.6178797	total: 56.6ms	remaining: 37.7ms
# 30:	learn: 0.6156186	total: 58.3ms	remaining: 35.8ms
# 31:	learn: 0.6133242	total: 60.3ms	remaining: 33.9ms
# 32:	learn: 0.6111677	total: 62.2ms	remaining: 32ms
# 33:	learn: 0.6090631	total: 63.8ms	remaining: 30ms
# 34:	learn: 0.6069459	total: 65.6ms	remaining: 28.1ms
# 35:	learn: 0.6047944	total: 67.4ms	remaining: 26.2ms
# 36:	learn: 0.6027666	total: 69.4ms	remaining: 24.4ms
# 37:	learn: 0.6007528	total: 71.2ms	remaining: 22.5ms
# 38:	learn: 0.5986926	total: 73ms	remaining: 20.6ms
# 39:	learn: 0.5967928	total: 74.1ms	remaining: 18.5ms
# 40:	learn: 0.5948890	total: 76.1ms	remaining: 16.7ms
# 41:	learn: 0.5929958	total: 77.9ms	remaining: 14.8ms
# 42:	learn: 0.5910336	total: 79.9ms	remaining: 13ms
# 43:	learn: 0.5892777	total: 81.1ms	remaining: 11.1ms
# 44:	learn: 0.5874380	total: 82.9ms	remaining: 9.21ms
# 45:	learn: 0.5856003	total: 84.6ms	remaining: 7.36ms
# 46:	learn: 0.5837924	total: 86.4ms	remaining: 5.51ms
# 47:	learn: 0.5820927	total: 88.2ms	remaining: 3.67ms
# 48:	learn: 0.5803664	total: 90.1ms	remaining: 1.84ms
# 49:	learn: 0.5786542	total: 91.8ms	remaining: 0us
# 0:	learn: 0.6652859	total: 2.23ms	remaining: 109ms
# 1:	learn: 0.6410612	total: 4.89ms	remaining: 117ms
# 2:	learn: 0.6201991	total: 7.03ms	remaining: 110ms
# 3:	learn: 0.6033023	total: 9.35ms	remaining: 107ms
# 4:	learn: 0.5836115	total: 12.8ms	remaining: 115ms
# 5:	learn: 0.5673194	total: 15ms	remaining: 110ms
# 6:	learn: 0.5530447	total: 17.5ms	remaining: 108ms
# 7:	learn: 0.5412878	total: 19.6ms	remaining: 103ms
# 8:	learn: 0.5312698	total: 21.8ms	remaining: 99.5ms
# 9:	learn: 0.5226819	total: 23.6ms	remaining: 94.5ms
# 10:	learn: 0.5147029	total: 25.7ms	remaining: 91ms
# 11:	learn: 0.5050141	total: 27.8ms	remaining: 88ms
# 12:	learn: 0.4976357	total: 29.2ms	remaining: 83.1ms
# 13:	learn: 0.4905132	total: 31.4ms	remaining: 80.8ms
# 14:	learn: 0.4843520	total: 33.5ms	remaining: 78.2ms
# 15:	learn: 0.4761759	total: 35.3ms	remaining: 75ms
# 16:	learn: 0.4686223	total: 37.5ms	remaining: 72.9ms
# 17:	learn: 0.4624094	total: 39.6ms	remaining: 70.4ms
# 18:	learn: 0.4573953	total: 41.6ms	remaining: 67.9ms
# 19:	learn: 0.4532281	total: 43.3ms	remaining: 64.9ms
# 20:	learn: 0.4496018	total: 45.5ms	remaining: 62.8ms
# 21:	learn: 0.4461861	total: 47.6ms	remaining: 60.5ms
# 22:	learn: 0.4436512	total: 49.3ms	remaining: 57.8ms
# 23:	learn: 0.4408238	total: 51.2ms	remaining: 55.5ms
# 24:	learn: 0.4383998	total: 53.4ms	remaining: 53.4ms
# 25:	learn: 0.4363716	total: 55.6ms	remaining: 51.3ms
# 26:	learn: 0.4341767	total: 57.7ms	remaining: 49.1ms
# 27:	learn: 0.4324293	total: 59.7ms	remaining: 46.9ms
# 28:	learn: 0.4310329	total: 61.9ms	remaining: 44.8ms
# 29:	learn: 0.4294342	total: 63.9ms	remaining: 42.6ms
# 30:	learn: 0.4277498	total: 65.8ms	remaining: 40.3ms
# 31:	learn: 0.4266218	total: 67.8ms	remaining: 38.2ms
# 32:	learn: 0.4259231	total: 69.9ms	remaining: 36ms
# 33:	learn: 0.4252188	total: 71.8ms	remaining: 33.8ms
# 34:	learn: 0.4245610	total: 73.8ms	remaining: 31.6ms
# 35:	learn: 0.4237912	total: 75.8ms	remaining: 29.5ms
# 36:	learn: 0.4235031	total: 77.1ms	remaining: 27.1ms
# 37:	learn: 0.4227379	total: 79.1ms	remaining: 25ms
# 38:	learn: 0.4220848	total: 81.1ms	remaining: 22.9ms
# 39:	learn: 0.4214594	total: 83.1ms	remaining: 20.8ms
# 40:	learn: 0.4209555	total: 85.2ms	remaining: 18.7ms
# 41:	learn: 0.4203062	total: 87.2ms	remaining: 16.6ms
# 42:	learn: 0.4199961	total: 88.5ms	remaining: 14.4ms
# 43:	learn: 0.4193669	total: 90.7ms	remaining: 12.4ms
# 44:	learn: 0.4189574	total: 92.8ms	remaining: 10.3ms
# 45:	learn: 0.4186644	total: 94.8ms	remaining: 8.24ms
# 46:	learn: 0.4182512	total: 96.9ms	remaining: 6.19ms
# 47:	learn: 0.4179338	total: 98.9ms	remaining: 4.12ms
# 48:	learn: 0.4175321	total: 101ms	remaining: 2.06ms
# 49:	learn: 0.4171598	total: 103ms	remaining: 0us
# 0:	learn: 0.6650000	total: 2.08ms	remaining: 102ms
# 1:	learn: 0.6402888	total: 4.45ms	remaining: 107ms
# 2:	learn: 0.6193603	total: 6.56ms	remaining: 103ms
# 3:	learn: 0.6015347	total: 8.56ms	remaining: 98.4ms
# 4:	learn: 0.5789024	total: 10.8ms	remaining: 96.9ms
# 5:	learn: 0.5609547	total: 13.5ms	remaining: 99ms
# 6:	learn: 0.5436934	total: 16ms	remaining: 98.3ms
# 7:	learn: 0.5299539	total: 17.8ms	remaining: 93.7ms
# 8:	learn: 0.5183121	total: 19.8ms	remaining: 90.3ms
# 9:	learn: 0.5082398	total: 21.8ms	remaining: 87.3ms
# 10:	learn: 0.5006472	total: 23.8ms	remaining: 84.5ms
# 11:	learn: 0.4926577	total: 27ms	remaining: 85.4ms
# 12:	learn: 0.4839543	total: 29.8ms	remaining: 84.7ms
# 13:	learn: 0.4759821	total: 31.8ms	remaining: 81.7ms
# 14:	learn: 0.4694329	total: 34.5ms	remaining: 80.4ms
# 15:	learn: 0.4646713	total: 35.8ms	remaining: 76.1ms
# 16:	learn: 0.4597152	total: 38.1ms	remaining: 73.9ms
# 17:	learn: 0.4554071	total: 40.5ms	remaining: 71.9ms
# 18:	learn: 0.4511332	total: 43.5ms	remaining: 71ms
# 19:	learn: 0.4472822	total: 45.6ms	remaining: 68.4ms
# 20:	learn: 0.4449008	total: 46.9ms	remaining: 64.8ms
# 21:	learn: 0.4415909	total: 48.8ms	remaining: 62.1ms
# 22:	learn: 0.4398261	total: 50.8ms	remaining: 59.6ms
# 23:	learn: 0.4380111	total: 52.6ms	remaining: 57ms
# 24:	learn: 0.4358214	total: 55.6ms	remaining: 55.6ms
# 25:	learn: 0.4342002	total: 58.1ms	remaining: 53.6ms
# 26:	learn: 0.4327089	total: 60ms	remaining: 51.1ms
# 27:	learn: 0.4310958	total: 62ms	remaining: 48.7ms
# 28:	learn: 0.4296622	total: 63.9ms	remaining: 46.2ms
# 29:	learn: 0.4287698	total: 66ms	remaining: 44ms
# 30:	learn: 0.4275412	total: 67.8ms	remaining: 41.6ms
# 31:	learn: 0.4262170	total: 69.9ms	remaining: 39.3ms
# 32:	learn: 0.4247172	total: 71.8ms	remaining: 37ms
# 33:	learn: 0.4238880	total: 73.8ms	remaining: 34.7ms
# 34:	learn: 0.4230834	total: 75.7ms	remaining: 32.4ms
# 35:	learn: 0.4224927	total: 77.7ms	remaining: 30.2ms
# 36:	learn: 0.4221293	total: 79.2ms	remaining: 27.8ms
# 37:	learn: 0.4215839	total: 80.8ms	remaining: 25.5ms
# 38:	learn: 0.4212511	total: 82.8ms	remaining: 23.4ms
# 39:	learn: 0.4204555	total: 84.8ms	remaining: 21.2ms
# 40:	learn: 0.4200404	total: 86.9ms	remaining: 19.1ms
# 41:	learn: 0.4197943	total: 88.4ms	remaining: 16.8ms
# 42:	learn: 0.4193680	total: 90.2ms	remaining: 14.7ms
# 43:	learn: 0.4189189	total: 92.1ms	remaining: 12.6ms
# 44:	learn: 0.4185827	total: 93.7ms	remaining: 10.4ms
# 45:	learn: 0.4182417	total: 95.6ms	remaining: 8.31ms
# 46:	learn: 0.4182051	total: 97.2ms	remaining: 6.2ms
# 47:	learn: 0.4178748	total: 99ms	remaining: 4.13ms
# 48:	learn: 0.4175831	total: 101ms	remaining: 2.06ms
# 49:	learn: 0.4171445	total: 103ms	remaining: 0us
# 0:	learn: 0.6645800	total: 2.59ms	remaining: 127ms
# 1:	learn: 0.6392676	total: 5.34ms	remaining: 128ms
# 2:	learn: 0.6195062	total: 7.47ms	remaining: 117ms
# 3:	learn: 0.5976392	total: 9.1ms	remaining: 105ms
# 4:	learn: 0.5792413	total: 10.8ms	remaining: 97.6ms
# 5:	learn: 0.5626738	total: 12.8ms	remaining: 93.9ms
# 6:	learn: 0.5493877	total: 14.6ms	remaining: 89.4ms
# 7:	learn: 0.5382177	total: 15.8ms	remaining: 83ms
# 8:	learn: 0.5286793	total: 16.9ms	remaining: 77.2ms
# 9:	learn: 0.5137760	total: 18.9ms	remaining: 75.6ms
# 10:	learn: 0.5011803	total: 20.8ms	remaining: 73.9ms
# 11:	learn: 0.4905823	total: 22.7ms	remaining: 71.9ms
# 12:	learn: 0.4828876	total: 24.4ms	remaining: 69.6ms
# 13:	learn: 0.4745775	total: 26.5ms	remaining: 68.1ms
# 14:	learn: 0.4684369	total: 28.4ms	remaining: 66.3ms
# 15:	learn: 0.4627266	total: 30.3ms	remaining: 64.5ms
# 16:	learn: 0.4585115	total: 31.9ms	remaining: 62ms
# 17:	learn: 0.4537177	total: 33.8ms	remaining: 60ms
# 18:	learn: 0.4501340	total: 35.6ms	remaining: 58.1ms
# 19:	learn: 0.4470165	total: 37.5ms	remaining: 56.3ms
# 20:	learn: 0.4431460	total: 39.5ms	remaining: 54.6ms
# 21:	learn: 0.4401846	total: 41.5ms	remaining: 52.8ms
# 22:	learn: 0.4375870	total: 43.4ms	remaining: 51ms
# 23:	learn: 0.4353294	total: 45.2ms	remaining: 49ms
# 24:	learn: 0.4327850	total: 47.1ms	remaining: 47.1ms
# 25:	learn: 0.4308340	total: 49.2ms	remaining: 45.4ms
# 26:	learn: 0.4288586	total: 51ms	remaining: 43.5ms
# 27:	learn: 0.4270799	total: 53.1ms	remaining: 41.7ms
# 28:	learn: 0.4253574	total: 55ms	remaining: 39.8ms
# 29:	learn: 0.4240583	total: 57ms	remaining: 38ms
# 30:	learn: 0.4228501	total: 59ms	remaining: 36.2ms
# 31:	learn: 0.4218255	total: 60.8ms	remaining: 34.2ms
# 32:	learn: 0.4210234	total: 62.8ms	remaining: 32.3ms
# 33:	learn: 0.4204788	total: 64.2ms	remaining: 30.2ms
# 34:	learn: 0.4199851	total: 65.8ms	remaining: 28.2ms
# 35:	learn: 0.4193886	total: 67.7ms	remaining: 26.3ms
# 36:	learn: 0.4185368	total: 69.7ms	remaining: 24.5ms
# 37:	learn: 0.4178133	total: 71.8ms	remaining: 22.7ms
# 38:	learn: 0.4173012	total: 73.7ms	remaining: 20.8ms
# 39:	learn: 0.4171008	total: 75.7ms	remaining: 18.9ms
# 40:	learn: 0.4168869	total: 77.8ms	remaining: 17.1ms
# 41:	learn: 0.4166604	total: 79.7ms	remaining: 15.2ms
# 42:	learn: 0.4165101	total: 81.6ms	remaining: 13.3ms
# 43:	learn: 0.4161762	total: 83.4ms	remaining: 11.4ms
# 44:	learn: 0.4160395	total: 84.7ms	remaining: 9.41ms
# 45:	learn: 0.4155810	total: 86.7ms	remaining: 7.54ms
# 46:	learn: 0.4152508	total: 88.7ms	remaining: 5.66ms
# 47:	learn: 0.4151415	total: 90.6ms	remaining: 3.78ms
# 48:	learn: 0.4146384	total: 92.5ms	remaining: 1.89ms
# 49:	learn: 0.4143054	total: 93.6ms	remaining: 0us
# 0:	learn: 0.6643596	total: 2.44ms	remaining: 120ms
# 1:	learn: 0.6385328	total: 4.79ms	remaining: 115ms
# 2:	learn: 0.6185507	total: 6.67ms	remaining: 104ms
# 3:	learn: 0.6002143	total: 8.76ms	remaining: 101ms
# 4:	learn: 0.5850281	total: 10.7ms	remaining: 96.1ms
# 5:	learn: 0.5674127	total: 12.7ms	remaining: 93ms
# 6:	learn: 0.5536589	total: 14.5ms	remaining: 89.1ms
# 7:	learn: 0.5407112	total: 16.4ms	remaining: 86.1ms
# 8:	learn: 0.5320459	total: 17.6ms	remaining: 80.3ms
# 9:	learn: 0.5225339	total: 19.6ms	remaining: 78.5ms
# 10:	learn: 0.5097892	total: 21.5ms	remaining: 76.2ms
# 11:	learn: 0.5003945	total: 23.4ms	remaining: 74.3ms
# 12:	learn: 0.4922512	total: 25.2ms	remaining: 71.7ms
# 13:	learn: 0.4840763	total: 27.3ms	remaining: 70.1ms
# 14:	learn: 0.4786136	total: 29.3ms	remaining: 68.4ms
# 15:	learn: 0.4732271	total: 31.2ms	remaining: 66.3ms
# 16:	learn: 0.4680829	total: 33.3ms	remaining: 64.7ms
# 17:	learn: 0.4619268	total: 35.5ms	remaining: 63.1ms
# 18:	learn: 0.4565195	total: 37.7ms	remaining: 61.5ms
# 19:	learn: 0.4517773	total: 39.6ms	remaining: 59.5ms
# 20:	learn: 0.4479034	total: 41.6ms	remaining: 57.5ms
# 21:	learn: 0.4439468	total: 43.6ms	remaining: 55.5ms
# 22:	learn: 0.4410901	total: 45.1ms	remaining: 53ms
# 23:	learn: 0.4386236	total: 46.7ms	remaining: 50.6ms
# 24:	learn: 0.4361168	total: 48.5ms	remaining: 48.5ms
# 25:	learn: 0.4340897	total: 50.6ms	remaining: 46.7ms
# 26:	learn: 0.4317015	total: 52.8ms	remaining: 45ms
# 27:	learn: 0.4298113	total: 54.9ms	remaining: 43.1ms
# 28:	learn: 0.4282438	total: 57ms	remaining: 41.3ms
# 29:	learn: 0.4266469	total: 58.9ms	remaining: 39.2ms
# 30:	learn: 0.4257246	total: 60.9ms	remaining: 37.3ms
# 31:	learn: 0.4246837	total: 63.1ms	remaining: 35.5ms
# 32:	learn: 0.4236871	total: 64.9ms	remaining: 33.4ms
# 33:	learn: 0.4226294	total: 66.9ms	remaining: 31.5ms
# 34:	learn: 0.4218605	total: 68.8ms	remaining: 29.5ms
# 35:	learn: 0.4210964	total: 71ms	remaining: 27.6ms
# 36:	learn: 0.4205037	total: 72.8ms	remaining: 25.6ms
# 37:	learn: 0.4200829	total: 75ms	remaining: 23.7ms
# 38:	learn: 0.4195734	total: 77.1ms	remaining: 21.7ms
# 39:	learn: 0.4189713	total: 78.9ms	remaining: 19.7ms
# 40:	learn: 0.4182334	total: 81ms	remaining: 17.8ms
# 41:	learn: 0.4176664	total: 83ms	remaining: 15.8ms
# 42:	learn: 0.4171736	total: 85ms	remaining: 13.8ms
# 43:	learn: 0.4169820	total: 86.7ms	remaining: 11.8ms
# 44:	learn: 0.4167509	total: 88.6ms	remaining: 9.85ms
# 45:	learn: 0.4161636	total: 90.6ms	remaining: 7.88ms
# 46:	learn: 0.4160264	total: 92.3ms	remaining: 5.89ms
# 47:	learn: 0.4157134	total: 94.2ms	remaining: 3.92ms
# 48:	learn: 0.4156203	total: 95.7ms	remaining: 1.95ms
# 49:	learn: 0.4151696	total: 97.7ms	remaining: 0us
# 0:	learn: 0.6643221	total: 2.4ms	remaining: 118ms
# 1:	learn: 0.6384825	total: 4.78ms	remaining: 115ms
# 2:	learn: 0.6184305	total: 6.61ms	remaining: 104ms
# 3:	learn: 0.5998350	total: 8.6ms	remaining: 98.9ms
# 4:	learn: 0.5843496	total: 10.4ms	remaining: 93.8ms
# 5:	learn: 0.5668526	total: 12.2ms	remaining: 89.8ms
# 6:	learn: 0.5524082	total: 14.1ms	remaining: 86.7ms
# 7:	learn: 0.5405470	total: 15.6ms	remaining: 81.9ms
# 8:	learn: 0.5304791	total: 17.1ms	remaining: 77.8ms
# 9:	learn: 0.5209662	total: 18.8ms	remaining: 75.1ms
# 10:	learn: 0.5084823	total: 20.7ms	remaining: 73.4ms
# 11:	learn: 0.4990834	total: 22.6ms	remaining: 71.4ms
# 12:	learn: 0.4907082	total: 24.6ms	remaining: 69.9ms
# 13:	learn: 0.4833120	total: 26.7ms	remaining: 68.8ms
# 14:	learn: 0.4776844	total: 29.6ms	remaining: 69.1ms
# 15:	learn: 0.4728681	total: 32.4ms	remaining: 68.9ms
# 16:	learn: 0.4678005	total: 34.4ms	remaining: 66.7ms
# 17:	learn: 0.4617788	total: 36.1ms	remaining: 64.2ms
# 18:	learn: 0.4566725	total: 38.1ms	remaining: 62.1ms
# 19:	learn: 0.4519841	total: 39.9ms	remaining: 59.9ms
# 20:	learn: 0.4482705	total: 42ms	remaining: 57.9ms
# 21:	learn: 0.4445095	total: 43.9ms	remaining: 55.9ms
# 22:	learn: 0.4416447	total: 45.4ms	remaining: 53.3ms
# 23:	learn: 0.4391956	total: 47ms	remaining: 50.9ms
# 24:	learn: 0.4367487	total: 49ms	remaining: 49ms
# 25:	learn: 0.4344667	total: 50.9ms	remaining: 47ms
# 26:	learn: 0.4319482	total: 52.8ms	remaining: 45ms
# 27:	learn: 0.4300653	total: 54.7ms	remaining: 43ms
# 28:	learn: 0.4283997	total: 56.7ms	remaining: 41ms
# 29:	learn: 0.4268026	total: 58.7ms	remaining: 39.1ms
# 30:	learn: 0.4258284	total: 60.7ms	remaining: 37.2ms
# 31:	learn: 0.4245753	total: 62.7ms	remaining: 35.3ms
# 32:	learn: 0.4239437	total: 65ms	remaining: 33.5ms
# 33:	learn: 0.4232682	total: 66.5ms	remaining: 31.3ms
# 34:	learn: 0.4222005	total: 68.6ms	remaining: 29.4ms
# 35:	learn: 0.4214663	total: 70.5ms	remaining: 27.4ms
# 36:	learn: 0.4207562	total: 72.5ms	remaining: 25.5ms
# 37:	learn: 0.4203473	total: 74.6ms	remaining: 23.6ms
# 38:	learn: 0.4196166	total: 76.5ms	remaining: 21.6ms
# 39:	learn: 0.4189935	total: 78.4ms	remaining: 19.6ms
# 40:	learn: 0.4183337	total: 80.2ms	remaining: 17.6ms
# 41:	learn: 0.4179782	total: 81.9ms	remaining: 15.6ms
# 42:	learn: 0.4175044	total: 83.9ms	remaining: 13.7ms
# 43:	learn: 0.4171011	total: 85.9ms	remaining: 11.7ms
# 44:	learn: 0.4169485	total: 87.8ms	remaining: 9.75ms
# 45:	learn: 0.4166338	total: 89.8ms	remaining: 7.81ms
# 46:	learn: 0.4163235	total: 91.8ms	remaining: 5.86ms
# 47:	learn: 0.4158722	total: 93.8ms	remaining: 3.91ms
# 48:	learn: 0.4157041	total: 95.8ms	remaining: 1.95ms
# 49:	learn: 0.4152802	total: 97.7ms	remaining: 0us
# 0:	learn: 0.6182484	total: 1.96ms	remaining: 96.2ms
# 1:	learn: 0.5732597	total: 4.38ms	remaining: 105ms
# 2:	learn: 0.5326537	total: 6.52ms	remaining: 102ms
# 3:	learn: 0.5075165	total: 8.44ms	remaining: 97ms
# 4:	learn: 0.4801802	total: 10.9ms	remaining: 98ms
# 5:	learn: 0.4630250	total: 12.9ms	remaining: 94.6ms
# 6:	learn: 0.4520996	total: 14.9ms	remaining: 91.8ms
# 7:	learn: 0.4422107	total: 16.9ms	remaining: 89ms
# 8:	learn: 0.4348034	total: 18.9ms	remaining: 85.9ms
# 9:	learn: 0.4310597	total: 20.6ms	remaining: 82.2ms
# 10:	learn: 0.4268878	total: 22.6ms	remaining: 80.2ms
# 11:	learn: 0.4244145	total: 24.8ms	remaining: 78.5ms
# 12:	learn: 0.4231580	total: 26.7ms	remaining: 75.9ms
# 13:	learn: 0.4203601	total: 28.6ms	remaining: 73.5ms
# 14:	learn: 0.4189953	total: 30.3ms	remaining: 70.8ms
# 15:	learn: 0.4185086	total: 32.3ms	remaining: 68.5ms
# 16:	learn: 0.4175868	total: 34.3ms	remaining: 66.6ms
# 17:	learn: 0.4168404	total: 36.2ms	remaining: 64.3ms
# 18:	learn: 0.4166246	total: 38.1ms	remaining: 62.2ms
# 19:	learn: 0.4163121	total: 39.8ms	remaining: 59.7ms
# 20:	learn: 0.4159335	total: 41.8ms	remaining: 57.7ms
# 21:	learn: 0.4158099	total: 43.8ms	remaining: 55.7ms
# 22:	learn: 0.4148199	total: 45.9ms	remaining: 53.9ms
# 23:	learn: 0.4143670	total: 47.9ms	remaining: 51.9ms
# 24:	learn: 0.4142646	total: 49.7ms	remaining: 49.7ms
# 25:	learn: 0.4139890	total: 51.7ms	remaining: 47.7ms
# 26:	learn: 0.4132514	total: 53.4ms	remaining: 45.5ms
# 27:	learn: 0.4128247	total: 55.4ms	remaining: 43.5ms
# 28:	learn: 0.4124465	total: 57.2ms	remaining: 41.4ms
# 29:	learn: 0.4124053	total: 59ms	remaining: 39.3ms
# 30:	learn: 0.4120003	total: 61ms	remaining: 37.4ms
# 31:	learn: 0.4114688	total: 63ms	remaining: 35.4ms
# 32:	learn: 0.4112688	total: 64.8ms	remaining: 33.4ms
# 33:	learn: 0.4110761	total: 66.8ms	remaining: 31.4ms
# 34:	learn: 0.4109508	total: 68.7ms	remaining: 29.5ms
# 35:	learn: 0.4106983	total: 70.7ms	remaining: 27.5ms
# 36:	learn: 0.4095008	total: 72.5ms	remaining: 25.5ms
# 37:	learn: 0.4092196	total: 74.4ms	remaining: 23.5ms
# 38:	learn: 0.4090814	total: 76.3ms	remaining: 21.5ms
# 39:	learn: 0.4088491	total: 78.3ms	remaining: 19.6ms
# 40:	learn: 0.4085748	total: 80.2ms	remaining: 17.6ms
# 41:	learn: 0.4083519	total: 82.2ms	remaining: 15.7ms
# 42:	learn: 0.4074849	total: 84.3ms	remaining: 13.7ms
# 43:	learn: 0.4074510	total: 86.2ms	remaining: 11.8ms
# 44:	learn: 0.4064553	total: 88.3ms	remaining: 9.81ms
# 45:	learn: 0.4062313	total: 90.3ms	remaining: 7.85ms
# 46:	learn: 0.4053838	total: 92.4ms	remaining: 5.9ms
# 47:	learn: 0.4050514	total: 94.3ms	remaining: 3.93ms
# 48:	learn: 0.4048916	total: 96.3ms	remaining: 1.96ms
# 49:	learn: 0.4043235	total: 98.2ms	remaining: 0us
# 0:	learn: 0.6174827	total: 2.05ms	remaining: 100ms
# 1:	learn: 0.5541247	total: 4.5ms	remaining: 108ms
# 2:	learn: 0.5120094	total: 6.47ms	remaining: 101ms
# 3:	learn: 0.4876406	total: 8.29ms	remaining: 95.3ms
# 4:	learn: 0.4670243	total: 10.1ms	remaining: 90.5ms
# 5:	learn: 0.4525285	total: 11.9ms	remaining: 87.5ms
# 6:	learn: 0.4440876	total: 13.8ms	remaining: 84.7ms
# 7:	learn: 0.4371041	total: 15.7ms	remaining: 82.5ms
# 8:	learn: 0.4323430	total: 17.8ms	remaining: 81.2ms
# 9:	learn: 0.4282975	total: 19.7ms	remaining: 78.9ms
# 10:	learn: 0.4244213	total: 21.8ms	remaining: 77.2ms
# 11:	learn: 0.4221819	total: 23.7ms	remaining: 75.1ms
# 12:	learn: 0.4212666	total: 25.6ms	remaining: 72.9ms
# 13:	learn: 0.4200957	total: 26.7ms	remaining: 68.6ms
# 14:	learn: 0.4194099	total: 28.6ms	remaining: 66.8ms
# 15:	learn: 0.4183758	total: 30.5ms	remaining: 64.9ms
# 16:	learn: 0.4176576	total: 32.6ms	remaining: 63.2ms
# 17:	learn: 0.4166778	total: 34.5ms	remaining: 61.3ms
# 18:	learn: 0.4161442	total: 36.4ms	remaining: 59.4ms
# 19:	learn: 0.4153522	total: 38.4ms	remaining: 57.6ms
# 20:	learn: 0.4149859	total: 40.3ms	remaining: 55.7ms
# 21:	learn: 0.4148713	total: 42.2ms	remaining: 53.7ms
# 22:	learn: 0.4140786	total: 43.9ms	remaining: 51.5ms
# 23:	learn: 0.4140048	total: 45.8ms	remaining: 49.6ms
# 24:	learn: 0.4139733	total: 47.3ms	remaining: 47.3ms
# 25:	learn: 0.4137242	total: 49.3ms	remaining: 45.5ms
# 26:	learn: 0.4133305	total: 51.2ms	remaining: 43.6ms
# 27:	learn: 0.4132915	total: 53.1ms	remaining: 41.7ms
# 28:	learn: 0.4132095	total: 55.1ms	remaining: 39.9ms
# 29:	learn: 0.4128496	total: 57ms	remaining: 38ms
# 30:	learn: 0.4128328	total: 58.9ms	remaining: 36.1ms
# 31:	learn: 0.4128111	total: 60.6ms	remaining: 34.1ms
# 32:	learn: 0.4127591	total: 62.5ms	remaining: 32.2ms
# 33:	learn: 0.4119679	total: 64.3ms	remaining: 30.2ms
# 34:	learn: 0.4118592	total: 66.2ms	remaining: 28.4ms
# 35:	learn: 0.4118562	total: 68ms	remaining: 26.5ms
# 36:	learn: 0.4113726	total: 70.1ms	remaining: 24.6ms
# 37:	learn: 0.4109307	total: 72.1ms	remaining: 22.8ms
# 38:	learn: 0.4109249	total: 73.8ms	remaining: 20.8ms
# 39:	learn: 0.4101639	total: 75.8ms	remaining: 18.9ms
# 40:	learn: 0.4101584	total: 77.6ms	remaining: 17ms
# 41:	learn: 0.4101543	total: 79.5ms	remaining: 15.2ms
# 42:	learn: 0.4101508	total: 81.5ms	remaining: 13.3ms
# 43:	learn: 0.4099034	total: 83.4ms	remaining: 11.4ms
# 44:	learn: 0.4097559	total: 85.4ms	remaining: 9.49ms
# 45:	learn: 0.4096297	total: 87.6ms	remaining: 7.62ms
# 46:	learn: 0.4093214	total: 89.6ms	remaining: 5.72ms
# 47:	learn: 0.4092907	total: 91.6ms	remaining: 3.81ms
# 48:	learn: 0.4092470	total: 93.4ms	remaining: 1.91ms
# 49:	learn: 0.4092395	total: 95.4ms	remaining: 0us
# 0:	learn: 0.6163046	total: 2.35ms	remaining: 115ms
# 1:	learn: 0.5704619	total: 4.58ms	remaining: 110ms
# 2:	learn: 0.5300022	total: 6.59ms	remaining: 103ms
# 3:	learn: 0.5037629	total: 8.88ms	remaining: 102ms
# 4:	learn: 0.4885204	total: 10.6ms	remaining: 95.4ms
# 5:	learn: 0.4727210	total: 12.5ms	remaining: 91.5ms
# 6:	learn: 0.4542080	total: 14ms	remaining: 85.7ms
# 7:	learn: 0.4412894	total: 15.9ms	remaining: 83.3ms
# 8:	learn: 0.4344560	total: 17.9ms	remaining: 81.4ms
# 9:	learn: 0.4297829	total: 19.6ms	remaining: 78.6ms
# 10:	learn: 0.4267463	total: 21.6ms	remaining: 76.6ms
# 11:	learn: 0.4231395	total: 23.5ms	remaining: 74.5ms
# 12:	learn: 0.4212657	total: 25.6ms	remaining: 72.8ms
# 13:	learn: 0.4187398	total: 27.5ms	remaining: 70.8ms
# 14:	learn: 0.4170741	total: 29.5ms	remaining: 68.8ms
# 15:	learn: 0.4164413	total: 31.4ms	remaining: 66.8ms
# 16:	learn: 0.4155271	total: 33.4ms	remaining: 64.8ms
# 17:	learn: 0.4141906	total: 35.4ms	remaining: 62.9ms
# 18:	learn: 0.4137033	total: 37.3ms	remaining: 60.8ms
# 19:	learn: 0.4127593	total: 39.2ms	remaining: 58.8ms
# 20:	learn: 0.4119643	total: 41.2ms	remaining: 56.9ms
# 21:	learn: 0.4117696	total: 43.1ms	remaining: 54.9ms
# 22:	learn: 0.4112573	total: 45.1ms	remaining: 52.9ms
# 23:	learn: 0.4109848	total: 46.8ms	remaining: 50.7ms
# 24:	learn: 0.4108904	total: 48.7ms	remaining: 48.7ms
# 25:	learn: 0.4103245	total: 50.5ms	remaining: 46.6ms
# 26:	learn: 0.4102538	total: 52.4ms	remaining: 44.6ms
# 27:	learn: 0.4096709	total: 54.2ms	remaining: 42.6ms
# 28:	learn: 0.4089326	total: 56ms	remaining: 40.5ms
# 29:	learn: 0.4083840	total: 57.8ms	remaining: 38.6ms
# 30:	learn: 0.4075439	total: 59.8ms	remaining: 36.6ms
# 31:	learn: 0.4069170	total: 61.6ms	remaining: 34.7ms
# 32:	learn: 0.4063456	total: 63.5ms	remaining: 32.7ms
# 33:	learn: 0.4062767	total: 65.6ms	remaining: 30.9ms
# 34:	learn: 0.4062348	total: 67.4ms	remaining: 28.9ms
# 35:	learn: 0.4060185	total: 69.3ms	remaining: 26.9ms
# 36:	learn: 0.4052818	total: 71.1ms	remaining: 25ms
# 37:	learn: 0.4047202	total: 73.1ms	remaining: 23.1ms
# 38:	learn: 0.4045521	total: 75.1ms	remaining: 21.2ms
# 39:	learn: 0.4035862	total: 77ms	remaining: 19.2ms
# 40:	learn: 0.4034525	total: 78.9ms	remaining: 17.3ms
# 41:	learn: 0.4026487	total: 80.7ms	remaining: 15.4ms
# 42:	learn: 0.4022848	total: 82.7ms	remaining: 13.5ms
# 43:	learn: 0.4020760	total: 84.6ms	remaining: 11.5ms
# 44:	learn: 0.4018330	total: 86.4ms	remaining: 9.6ms
# 45:	learn: 0.4015139	total: 88.3ms	remaining: 7.67ms
# 46:	learn: 0.4014100	total: 90.2ms	remaining: 5.75ms
# 47:	learn: 0.4005286	total: 92.2ms	remaining: 3.84ms
# 48:	learn: 0.4004142	total: 94ms	remaining: 1.92ms
# 49:	learn: 0.4003414	total: 95.9ms	remaining: 0us
# 0:	learn: 0.6157083	total: 2.39ms	remaining: 117ms
# 1:	learn: 0.5686482	total: 4.97ms	remaining: 119ms
# 2:	learn: 0.5292370	total: 6.41ms	remaining: 100ms
# 3:	learn: 0.5046200	total: 8.47ms	remaining: 97.4ms
# 4:	learn: 0.4754547	total: 10.6ms	remaining: 95.4ms
# 5:	learn: 0.4576313	total: 12.4ms	remaining: 90.9ms
# 6:	learn: 0.4465931	total: 14.3ms	remaining: 87.8ms
# 7:	learn: 0.4366513	total: 16.4ms	remaining: 86.2ms
# 8:	learn: 0.4324486	total: 18.4ms	remaining: 84ms
# 9:	learn: 0.4273145	total: 20.5ms	remaining: 81.9ms
# 10:	learn: 0.4241643	total: 22.3ms	remaining: 79.2ms
# 11:	learn: 0.4211357	total: 24.4ms	remaining: 77.2ms
# 12:	learn: 0.4191074	total: 26.4ms	remaining: 75.1ms
# 13:	learn: 0.4176805	total: 28.4ms	remaining: 73.1ms
# 14:	learn: 0.4168306	total: 30.3ms	remaining: 70.7ms
# 15:	learn: 0.4163632	total: 32.1ms	remaining: 68.2ms
# 16:	learn: 0.4160371	total: 33.9ms	remaining: 65.9ms
# 17:	learn: 0.4151934	total: 36ms	remaining: 63.9ms
# 18:	learn: 0.4148306	total: 37.9ms	remaining: 61.8ms
# 19:	learn: 0.4144355	total: 39.1ms	remaining: 58.7ms
# 20:	learn: 0.4134187	total: 41.1ms	remaining: 56.8ms
# 21:	learn: 0.4130485	total: 43ms	remaining: 54.7ms
# 22:	learn: 0.4129176	total: 45ms	remaining: 52.9ms
# 23:	learn: 0.4128121	total: 46.7ms	remaining: 50.6ms
# 24:	learn: 0.4127801	total: 48.8ms	remaining: 48.8ms
# 25:	learn: 0.4119126	total: 50.7ms	remaining: 46.8ms
# 26:	learn: 0.4114538	total: 52.7ms	remaining: 44.9ms
# 27:	learn: 0.4109819	total: 54.6ms	remaining: 42.9ms
# 28:	learn: 0.4108108	total: 56.5ms	remaining: 40.9ms
# 29:	learn: 0.4106845	total: 58.5ms	remaining: 39ms
# 30:	learn: 0.4103187	total: 60.5ms	remaining: 37.1ms
# 31:	learn: 0.4094455	total: 62.6ms	remaining: 35.2ms
# 32:	learn: 0.4093130	total: 64.7ms	remaining: 33.3ms
# 33:	learn: 0.4092744	total: 66.5ms	remaining: 31.3ms
# 34:	learn: 0.4087618	total: 68.4ms	remaining: 29.3ms
# 35:	learn: 0.4085380	total: 70.2ms	remaining: 27.3ms
# 36:	learn: 0.4083350	total: 72.3ms	remaining: 25.4ms
# 37:	learn: 0.4080664	total: 74.3ms	remaining: 23.5ms
# 38:	learn: 0.4077702	total: 76.2ms	remaining: 21.5ms
# 39:	learn: 0.4076695	total: 78.3ms	remaining: 19.6ms
# 40:	learn: 0.4069116	total: 80.1ms	remaining: 17.6ms
# 41:	learn: 0.4068168	total: 82.1ms	remaining: 15.6ms
# 42:	learn: 0.4067553	total: 84ms	remaining: 13.7ms
# 43:	learn: 0.4067114	total: 85.8ms	remaining: 11.7ms
# 44:	learn: 0.4065690	total: 87.8ms	remaining: 9.76ms
# 45:	learn: 0.4061823	total: 89.7ms	remaining: 7.8ms
# 46:	learn: 0.4056884	total: 91.7ms	remaining: 5.85ms
# 47:	learn: 0.4056093	total: 93.4ms	remaining: 3.89ms
# 48:	learn: 0.4049640	total: 95.3ms	remaining: 1.94ms
# 49:	learn: 0.4043418	total: 97.1ms	remaining: 0us
# 0:	learn: 0.6156336	total: 2.39ms	remaining: 117ms
# 1:	learn: 0.5700553	total: 4.85ms	remaining: 116ms
# 2:	learn: 0.5296455	total: 7.05ms	remaining: 110ms
# 3:	learn: 0.5053750	total: 9.1ms	remaining: 105ms
# 4:	learn: 0.4900435	total: 11ms	remaining: 98.6ms
# 5:	learn: 0.4744169	total: 12.3ms	remaining: 89.9ms
# 6:	learn: 0.4554232	total: 14.2ms	remaining: 87.3ms
# 7:	learn: 0.4433057	total: 16.1ms	remaining: 84.7ms
# 8:	learn: 0.4355777	total: 18ms	remaining: 82.2ms
# 9:	learn: 0.4313949	total: 19.5ms	remaining: 78ms
# 10:	learn: 0.4288110	total: 21.4ms	remaining: 75.9ms
# 11:	learn: 0.4246979	total: 23.4ms	remaining: 74.2ms
# 12:	learn: 0.4222980	total: 25.2ms	remaining: 71.8ms
# 13:	learn: 0.4211136	total: 27ms	remaining: 69.4ms
# 14:	learn: 0.4206150	total: 28.2ms	remaining: 65.8ms
# 15:	learn: 0.4201308	total: 30.1ms	remaining: 63.9ms
# 16:	learn: 0.4190610	total: 32.3ms	remaining: 62.8ms
# 17:	learn: 0.4178012	total: 34.5ms	remaining: 61.3ms
# 18:	learn: 0.4172804	total: 36.4ms	remaining: 59.3ms
# 19:	learn: 0.4163366	total: 38.4ms	remaining: 57.5ms
# 20:	learn: 0.4161780	total: 40.4ms	remaining: 55.8ms
# 21:	learn: 0.4156809	total: 42.5ms	remaining: 54.1ms
# 22:	learn: 0.4151349	total: 44.6ms	remaining: 52.3ms
# 23:	learn: 0.4143984	total: 46.7ms	remaining: 50.6ms
# 24:	learn: 0.4143064	total: 48.7ms	remaining: 48.7ms
# 25:	learn: 0.4138338	total: 50.5ms	remaining: 46.6ms
# 26:	learn: 0.4130603	total: 52.7ms	remaining: 44.9ms
# 27:	learn: 0.4123224	total: 54.5ms	remaining: 42.8ms
# 28:	learn: 0.4114936	total: 56.6ms	remaining: 41ms
# 29:	learn: 0.4114732	total: 58.3ms	remaining: 38.8ms
# 30:	learn: 0.4103074	total: 60.2ms	remaining: 36.9ms
# 31:	learn: 0.4098824	total: 62.1ms	remaining: 34.9ms
# 32:	learn: 0.4098297	total: 64.1ms	remaining: 33ms
# 33:	learn: 0.4097798	total: 66ms	remaining: 31ms
# 34:	learn: 0.4096690	total: 68.2ms	remaining: 29.2ms
# 35:	learn: 0.4083738	total: 70.2ms	remaining: 27.3ms
# 36:	learn: 0.4080877	total: 72.2ms	remaining: 25.4ms
# 37:	learn: 0.4077229	total: 74.2ms	remaining: 23.4ms
# 38:	learn: 0.4075377	total: 76.1ms	remaining: 21.5ms
# 39:	learn: 0.4072102	total: 78ms	remaining: 19.5ms
# 40:	learn: 0.4071641	total: 80ms	remaining: 17.6ms
# 41:	learn: 0.4064500	total: 81.9ms	remaining: 15.6ms
# 42:	learn: 0.4062840	total: 83.8ms	remaining: 13.6ms
# 43:	learn: 0.4061211	total: 85.8ms	remaining: 11.7ms
# 44:	learn: 0.4060622	total: 87.8ms	remaining: 9.76ms
# 45:	learn: 0.4057029	total: 89.6ms	remaining: 7.79ms
# 46:	learn: 0.4050872	total: 91.5ms	remaining: 5.84ms
# 47:	learn: 0.4048837	total: 93.6ms	remaining: 3.9ms
# 48:	learn: 0.4041088	total: 95.5ms	remaining: 1.95ms
# 49:	learn: 0.4037461	total: 97.4ms	remaining: 0us
# 0:	learn: 0.6902484	total: 2.45ms	remaining: 120ms
# 1:	learn: 0.6872948	total: 4.74ms	remaining: 114ms
# 2:	learn: 0.6843198	total: 6.91ms	remaining: 108ms
# 3:	learn: 0.6814979	total: 8.85ms	remaining: 102ms
# 4:	learn: 0.6789375	total: 10.8ms	remaining: 97.1ms
# 5:	learn: 0.6761066	total: 12.7ms	remaining: 92.9ms
# 6:	learn: 0.6735163	total: 14.9ms	remaining: 91.4ms
# 7:	learn: 0.6709470	total: 17ms	remaining: 89.4ms
# 8:	learn: 0.6682844	total: 18.9ms	remaining: 86.2ms
# 9:	learn: 0.6656976	total: 20.9ms	remaining: 83.5ms
# 10:	learn: 0.6631273	total: 22.7ms	remaining: 80.4ms
# 11:	learn: 0.6607360	total: 24.7ms	remaining: 78.2ms
# 12:	learn: 0.6584712	total: 26.7ms	remaining: 76ms
# 13:	learn: 0.6561303	total: 28.6ms	remaining: 73.5ms
# 14:	learn: 0.6538714	total: 30.6ms	remaining: 71.4ms
# 15:	learn: 0.6515714	total: 32.5ms	remaining: 69.1ms
# 16:	learn: 0.6494028	total: 34.5ms	remaining: 67ms
# 17:	learn: 0.6471203	total: 36.5ms	remaining: 64.8ms
# 18:	learn: 0.6449330	total: 38.1ms	remaining: 62.1ms
# 19:	learn: 0.6430565	total: 39.7ms	remaining: 59.6ms
# 20:	learn: 0.6408616	total: 41.5ms	remaining: 57.3ms
# 21:	learn: 0.6387696	total: 43.4ms	remaining: 55.2ms
# 22:	learn: 0.6367093	total: 45.2ms	remaining: 53ms
# 23:	learn: 0.6346273	total: 46.9ms	remaining: 50.8ms
# 24:	learn: 0.6326336	total: 48.7ms	remaining: 48.7ms
# 25:	learn: 0.6307689	total: 50.5ms	remaining: 46.7ms
# 26:	learn: 0.6283968	total: 51.9ms	remaining: 44.2ms
# 27:	learn: 0.6260511	total: 53.5ms	remaining: 42ms
# 28:	learn: 0.6236754	total: 55.3ms	remaining: 40ms
# 29:	learn: 0.6214337	total: 57.1ms	remaining: 38.1ms
# 30:	learn: 0.6191944	total: 58.7ms	remaining: 36ms
# 31:	learn: 0.6170294	total: 59.9ms	remaining: 33.7ms
# 32:	learn: 0.6148485	total: 61.7ms	remaining: 31.8ms
# 33:	learn: 0.6126894	total: 63.4ms	remaining: 29.9ms
# 34:	learn: 0.6106326	total: 64.7ms	remaining: 27.7ms
# 35:	learn: 0.6085267	total: 66.2ms	remaining: 25.7ms
# 36:	learn: 0.6064861	total: 68ms	remaining: 23.9ms
# 37:	learn: 0.6045419	total: 69.5ms	remaining: 21.9ms
# 38:	learn: 0.6025876	total: 71ms	remaining: 20ms
# 39:	learn: 0.6006415	total: 72.9ms	remaining: 18.2ms
# 40:	learn: 0.5987665	total: 74.7ms	remaining: 16.4ms
# 41:	learn: 0.5969320	total: 76ms	remaining: 14.5ms
# 42:	learn: 0.5951192	total: 77.9ms	remaining: 12.7ms
# 43:	learn: 0.5932570	total: 79.8ms	remaining: 10.9ms
# 44:	learn: 0.5913647	total: 81.7ms	remaining: 9.08ms
# 45:	learn: 0.5896506	total: 82.9ms	remaining: 7.21ms
# 46:	learn: 0.5878558	total: 84.9ms	remaining: 5.42ms
# 47:	learn: 0.5861238	total: 86.8ms	remaining: 3.62ms
# 48:	learn: 0.5844232	total: 88.5ms	remaining: 1.81ms
# 49:	learn: 0.5827987	total: 90.2ms	remaining: 0us
# 0:	learn: 0.6902171	total: 2.18ms	remaining: 107ms
# 1:	learn: 0.6871995	total: 4.78ms	remaining: 115ms
# 2:	learn: 0.6842082	total: 6.67ms	remaining: 104ms
# 3:	learn: 0.6812625	total: 8.6ms	remaining: 98.9ms
# 4:	learn: 0.6786650	total: 10.5ms	remaining: 94.7ms
# 5:	learn: 0.6758282	total: 12.3ms	remaining: 90.3ms
# 6:	learn: 0.6732017	total: 14.6ms	remaining: 89.8ms
# 7:	learn: 0.6706007	total: 16.6ms	remaining: 86.9ms
# 8:	learn: 0.6680280	total: 18.3ms	remaining: 83.5ms
# 9:	learn: 0.6653803	total: 20.2ms	remaining: 80.8ms
# 10:	learn: 0.6628172	total: 21.8ms	remaining: 77.4ms
# 11:	learn: 0.6604015	total: 23.7ms	remaining: 75ms
# 12:	learn: 0.6580925	total: 25.4ms	remaining: 72.4ms
# 13:	learn: 0.6557065	total: 27.3ms	remaining: 70.2ms
# 14:	learn: 0.6533960	total: 29.2ms	remaining: 68ms
# 15:	learn: 0.6510115	total: 31ms	remaining: 65.8ms
# 16:	learn: 0.6488376	total: 32.9ms	remaining: 64ms
# 17:	learn: 0.6465607	total: 34.8ms	remaining: 61.8ms
# 18:	learn: 0.6442965	total: 36.8ms	remaining: 60ms
# 19:	learn: 0.6424236	total: 38.6ms	remaining: 57.9ms
# 20:	learn: 0.6404988	total: 40.2ms	remaining: 55.5ms
# 21:	learn: 0.6383743	total: 42ms	remaining: 53.4ms
# 22:	learn: 0.6363269	total: 44ms	remaining: 51.6ms
# 23:	learn: 0.6343458	total: 45.8ms	remaining: 49.7ms
# 24:	learn: 0.6323385	total: 47.8ms	remaining: 47.8ms
# 25:	learn: 0.6303545	total: 49.8ms	remaining: 45.9ms
# 26:	learn: 0.6284213	total: 51.8ms	remaining: 44.1ms
# 27:	learn: 0.6264649	total: 53.9ms	remaining: 42.4ms
# 28:	learn: 0.6245863	total: 56ms	remaining: 40.5ms
# 29:	learn: 0.6223153	total: 57.4ms	remaining: 38.3ms
# 30:	learn: 0.6201010	total: 59ms	remaining: 36.1ms
# 31:	learn: 0.6179087	total: 60.2ms	remaining: 33.9ms
# 32:	learn: 0.6156809	total: 62ms	remaining: 32ms
# 33:	learn: 0.6134802	total: 64ms	remaining: 30.1ms
# 34:	learn: 0.6113982	total: 65.9ms	remaining: 28.3ms
# 35:	learn: 0.6092453	total: 67.8ms	remaining: 26.4ms
# 36:	learn: 0.6071513	total: 69.7ms	remaining: 24.5ms
# 37:	learn: 0.6050578	total: 71.6ms	remaining: 22.6ms
# 38:	learn: 0.6030053	total: 73.5ms	remaining: 20.7ms
# 39:	learn: 0.6009995	total: 75.5ms	remaining: 18.9ms
# 40:	learn: 0.5991034	total: 76.8ms	remaining: 16.9ms
# 41:	learn: 0.5971580	total: 78.8ms	remaining: 15ms
# 42:	learn: 0.5952695	total: 80.7ms	remaining: 13.1ms
# 43:	learn: 0.5934438	total: 82.5ms	remaining: 11.3ms
# 44:	learn: 0.5915482	total: 84.3ms	remaining: 9.37ms
# 45:	learn: 0.5897560	total: 86.5ms	remaining: 7.52ms
# 46:	learn: 0.5880156	total: 88.5ms	remaining: 5.65ms
# 47:	learn: 0.5862943	total: 90.3ms	remaining: 3.76ms
# 48:	learn: 0.5845579	total: 92.3ms	remaining: 1.88ms
# 49:	learn: 0.5828944	total: 94.1ms	remaining: 0us
# 0:	learn: 0.6901998	total: 4.09ms	remaining: 200ms
# 1:	learn: 0.6871244	total: 6.61ms	remaining: 159ms
# 2:	learn: 0.6843018	total: 8.57ms	remaining: 134ms
# 3:	learn: 0.6813416	total: 10.8ms	remaining: 124ms
# 4:	learn: 0.6787697	total: 12.7ms	remaining: 114ms
# 5:	learn: 0.6761428	total: 14.7ms	remaining: 108ms
# 6:	learn: 0.6735696	total: 16.4ms	remaining: 101ms
# 7:	learn: 0.6708362	total: 18.3ms	remaining: 95.9ms
# 8:	learn: 0.6683725	total: 20.1ms	remaining: 91.4ms
# 9:	learn: 0.6659400	total: 22ms	remaining: 88ms
# 10:	learn: 0.6634203	total: 23.9ms	remaining: 84.7ms
# 11:	learn: 0.6609329	total: 25.7ms	remaining: 81.3ms
# 12:	learn: 0.6585181	total: 27.6ms	remaining: 78.6ms
# 13:	learn: 0.6560945	total: 29.3ms	remaining: 75.4ms
# 14:	learn: 0.6537195	total: 31.3ms	remaining: 72.9ms
# 15:	learn: 0.6513655	total: 32.9ms	remaining: 70ms
# 16:	learn: 0.6490737	total: 34.8ms	remaining: 67.6ms
# 17:	learn: 0.6468533	total: 36.9ms	remaining: 65.6ms
# 18:	learn: 0.6446667	total: 38.7ms	remaining: 63.1ms
# 19:	learn: 0.6424541	total: 40.6ms	remaining: 60.9ms
# 20:	learn: 0.6403044	total: 42.5ms	remaining: 58.7ms
# 21:	learn: 0.6382661	total: 44.3ms	remaining: 56.3ms
# 22:	learn: 0.6361656	total: 46.1ms	remaining: 54.1ms
# 23:	learn: 0.6341047	total: 48ms	remaining: 51.9ms
# 24:	learn: 0.6321617	total: 49.6ms	remaining: 49.6ms
# 25:	learn: 0.6303433	total: 51.4ms	remaining: 47.4ms
# 26:	learn: 0.6278399	total: 53.2ms	remaining: 45.3ms
# 27:	learn: 0.6255182	total: 55.1ms	remaining: 43.3ms
# 28:	learn: 0.6230991	total: 56.9ms	remaining: 41.2ms
# 29:	learn: 0.6207495	total: 58.7ms	remaining: 39.1ms
# 30:	learn: 0.6184630	total: 60.4ms	remaining: 37ms
# 31:	learn: 0.6161983	total: 62.3ms	remaining: 35ms
# 32:	learn: 0.6140064	total: 64.1ms	remaining: 33ms
# 33:	learn: 0.6118596	total: 65.6ms	remaining: 30.9ms
# 34:	learn: 0.6096907	total: 67.5ms	remaining: 28.9ms
# 35:	learn: 0.6075633	total: 69.4ms	remaining: 27ms
# 36:	learn: 0.6054631	total: 71.2ms	remaining: 25ms
# 37:	learn: 0.6034594	total: 72.4ms	remaining: 22.9ms
# 38:	learn: 0.6014708	total: 74.4ms	remaining: 21ms
# 39:	learn: 0.5994703	total: 76.2ms	remaining: 19ms
# 40:	learn: 0.5974844	total: 77.6ms	remaining: 17ms
# 41:	learn: 0.5955284	total: 79.4ms	remaining: 15.1ms
# 42:	learn: 0.5936206	total: 81.2ms	remaining: 13.2ms
# 43:	learn: 0.5917691	total: 83.1ms	remaining: 11.3ms
# 44:	learn: 0.5899557	total: 84.9ms	remaining: 9.43ms
# 45:	learn: 0.5881233	total: 86.7ms	remaining: 7.54ms
# 46:	learn: 0.5863819	total: 88.7ms	remaining: 5.66ms
# 47:	learn: 0.5846635	total: 90.6ms	remaining: 3.77ms
# 48:	learn: 0.5829887	total: 91.9ms	remaining: 1.87ms
# 49:	learn: 0.5813795	total: 93.1ms	remaining: 0us
# 0:	learn: 0.6901763	total: 2.66ms	remaining: 130ms
# 1:	learn: 0.6870440	total: 4.96ms	remaining: 119ms
# 2:	learn: 0.6841962	total: 6.75ms	remaining: 106ms
# 3:	learn: 0.6811990	total: 8.86ms	remaining: 102ms
# 4:	learn: 0.6782682	total: 10.8ms	remaining: 97ms
# 5:	learn: 0.6756008	total: 12.6ms	remaining: 92.3ms
# 6:	learn: 0.6729515	total: 14.3ms	remaining: 88ms
# 7:	learn: 0.6701812	total: 16.1ms	remaining: 84.3ms
# 8:	learn: 0.6677051	total: 17.8ms	remaining: 80.9ms
# 9:	learn: 0.6652063	total: 19.7ms	remaining: 78.7ms
# 10:	learn: 0.6626494	total: 21.5ms	remaining: 76.1ms
# 11:	learn: 0.6601362	total: 23.3ms	remaining: 73.8ms
# 12:	learn: 0.6577237	total: 25.1ms	remaining: 71.5ms
# 13:	learn: 0.6553079	total: 26.6ms	remaining: 68.5ms
# 14:	learn: 0.6528773	total: 28.5ms	remaining: 66.5ms
# 15:	learn: 0.6505009	total: 30.1ms	remaining: 64ms
# 16:	learn: 0.6481695	total: 31.9ms	remaining: 62ms
# 17:	learn: 0.6459405	total: 33.6ms	remaining: 59.7ms
# ...
# 192:	learn: 0.1346746	total: 6.69s	remaining: 243ms
# 193:	learn: 0.1337461	total: 6.73s	remaining: 208ms
# 194:	learn: 0.1330625	total: 6.76s	remaining: 173ms
# 195:	learn: 0.1321100	total: 6.8s	remaining: 139ms
# 196:	learn: 0.1315646	total: 6.83s	remaining: 104ms
# 197:	learn: 0.1315531	total: 6.87s	remaining: 69.4ms
# 198:	learn: 0.1304507	total: 6.91s	remaining: 34.7ms
# 199:	learn: 0.1295943	total: 6.95s	remaining: 0us
# 0:	learn: 0.5594707	total: 7.99ms	remaining: 1.59s
# 1:	learn: 0.4889348	total: 13.3ms	remaining: 1.32s
# 2:	learn: 0.4553422	total: 20.5ms	remaining: 1.35s
# 3:	learn: 0.4407445	total: 28ms	remaining: 1.37s
# 4:	learn: 0.4172334	total: 61.5ms	remaining: 2.4s
# 5:	learn: 0.4118878	total: 68.9ms	remaining: 2.23s
# 6:	learn: 0.4086582	total: 76.3ms	remaining: 2.1s
# 7:	learn: 0.3981535	total: 106ms	remaining: 2.56s
# 8:	learn: 0.3878464	total: 140ms	remaining: 2.98s
# 9:	learn: 0.3819923	total: 174ms	remaining: 3.3s
# 10:	learn: 0.3806385	total: 190ms	remaining: 3.26s
# 11:	learn: 0.3713736	total: 220ms	remaining: 3.45s
# 12:	learn: 0.3713692	total: 223ms	remaining: 3.2s
# 13:	learn: 0.3712935	total: 229ms	remaining: 3.04s
# 14:	learn: 0.3689628	total: 264ms	remaining: 3.26s
# 15:	learn: 0.3614342	total: 301ms	remaining: 3.46s
# 16:	learn: 0.3602361	total: 314ms	remaining: 3.38s
# 17:	learn: 0.3602146	total: 318ms	remaining: 3.21s
# 18:	learn: 0.3601840	total: 325ms	remaining: 3.1s
# 19:	learn: 0.3590399	total: 361ms	remaining: 3.25s
# 20:	learn: 0.3590367	total: 364ms	remaining: 3.1s
# 21:	learn: 0.3584504	total: 375ms	remaining: 3.03s
# 22:	learn: 0.3560344	total: 413ms	remaining: 3.18s
# 23:	learn: 0.3505349	total: 458ms	remaining: 3.36s
# 24:	learn: 0.3467465	total: 501ms	remaining: 3.51s
# 25:	learn: 0.3467464	total: 503ms	remaining: 3.37s
# 26:	learn: 0.3467262	total: 508ms	remaining: 3.25s
# 27:	learn: 0.3445589	total: 543ms	remaining: 3.33s
# 28:	learn: 0.3415634	total: 586ms	remaining: 3.46s
# 29:	learn: 0.3366333	total: 627ms	remaining: 3.55s
# 30:	learn: 0.3364090	total: 634ms	remaining: 3.46s
# 31:	learn: 0.3359035	total: 673ms	remaining: 3.53s
# 32:	learn: 0.3284040	total: 705ms	remaining: 3.57s
# 33:	learn: 0.3249129	total: 743ms	remaining: 3.63s
# 34:	learn: 0.3247290	total: 782ms	remaining: 3.68s
# 35:	learn: 0.3185225	total: 817ms	remaining: 3.72s
# 36:	learn: 0.3141421	total: 850ms	remaining: 3.74s
# 37:	learn: 0.3130508	total: 892ms	remaining: 3.8s
# 38:	learn: 0.3110177	total: 930ms	remaining: 3.84s
# 39:	learn: 0.3092384	total: 964ms	remaining: 3.86s
# 40:	learn: 0.3047668	total: 1s	remaining: 3.89s
# 41:	learn: 0.3021822	total: 1.04s	remaining: 3.93s
# 42:	learn: 0.2976326	total: 1.08s	remaining: 3.96s
# 43:	learn: 0.2961810	total: 1.12s	remaining: 3.97s
# 44:	learn: 0.2914292	total: 1.15s	remaining: 3.97s
# 45:	learn: 0.2902446	total: 1.19s	remaining: 3.97s
# 46:	learn: 0.2874431	total: 1.22s	remaining: 3.97s
# 47:	learn: 0.2860590	total: 1.25s	remaining: 3.98s
# 48:	learn: 0.2845298	total: 1.29s	remaining: 3.99s
# 49:	learn: 0.2837811	total: 1.33s	remaining: 3.98s
# 50:	learn: 0.2836113	total: 1.36s	remaining: 3.98s
# 51:	learn: 0.2814745	total: 1.4s	remaining: 3.99s
# 52:	learn: 0.2792893	total: 1.44s	remaining: 4s
# 53:	learn: 0.2772205	total: 1.48s	remaining: 4s
# 54:	learn: 0.2765108	total: 1.52s	remaining: 4.01s
# 55:	learn: 0.2761565	total: 1.56s	remaining: 4.01s
# 56:	learn: 0.2724151	total: 1.59s	remaining: 4s
# 57:	learn: 0.2717044	total: 1.63s	remaining: 4s
# 58:	learn: 0.2707878	total: 1.67s	remaining: 3.98s
# 59:	learn: 0.2677495	total: 1.71s	remaining: 3.98s
# 60:	learn: 0.2651230	total: 1.75s	remaining: 3.98s
# 61:	learn: 0.2642281	total: 1.78s	remaining: 3.96s
# 62:	learn: 0.2623917	total: 1.82s	remaining: 3.97s
# 63:	learn: 0.2607938	total: 1.86s	remaining: 3.95s
# 64:	learn: 0.2596183	total: 1.89s	remaining: 3.93s
# 65:	learn: 0.2579933	total: 1.92s	remaining: 3.9s
# 66:	learn: 0.2545239	total: 1.96s	remaining: 3.89s
# 67:	learn: 0.2542900	total: 2s	remaining: 3.87s
# 68:	learn: 0.2527924	total: 2.03s	remaining: 3.85s
# 69:	learn: 0.2485391	total: 2.06s	remaining: 3.83s
# 70:	learn: 0.2477891	total: 2.09s	remaining: 3.8s
# 71:	learn: 0.2470621	total: 2.13s	remaining: 3.79s
# 72:	learn: 0.2465893	total: 2.17s	remaining: 3.77s
# 73:	learn: 0.2465312	total: 2.2s	remaining: 3.75s
# 74:	learn: 0.2431236	total: 2.24s	remaining: 3.74s
# 75:	learn: 0.2414670	total: 2.28s	remaining: 3.72s
# 76:	learn: 0.2404912	total: 2.31s	remaining: 3.69s
# 77:	learn: 0.2377187	total: 2.34s	remaining: 3.66s
# 78:	learn: 0.2357851	total: 2.37s	remaining: 3.63s
# 79:	learn: 0.2333656	total: 2.4s	remaining: 3.6s
# 80:	learn: 0.2326743	total: 2.44s	remaining: 3.58s
# 81:	learn: 0.2318119	total: 2.47s	remaining: 3.56s
# 82:	learn: 0.2307659	total: 2.51s	remaining: 3.54s
# 83:	learn: 0.2294574	total: 2.55s	remaining: 3.52s
# 84:	learn: 0.2280285	total: 2.59s	remaining: 3.5s
# 85:	learn: 0.2255794	total: 2.62s	remaining: 3.48s
# 86:	learn: 0.2245310	total: 2.65s	remaining: 3.45s
# 87:	learn: 0.2241321	total: 2.69s	remaining: 3.42s
# 88:	learn: 0.2225318	total: 2.73s	remaining: 3.4s
# 89:	learn: 0.2209736	total: 2.77s	remaining: 3.38s
# 90:	learn: 0.2204617	total: 2.8s	remaining: 3.35s
# 91:	learn: 0.2178655	total: 2.84s	remaining: 3.33s
# 92:	learn: 0.2166928	total: 2.88s	remaining: 3.31s
# 93:	learn: 0.2153483	total: 2.92s	remaining: 3.3s
# 94:	learn: 0.2139742	total: 2.96s	remaining: 3.27s
# 95:	learn: 0.2124441	total: 3s	remaining: 3.25s
# 96:	learn: 0.2121349	total: 3.03s	remaining: 3.22s
# 97:	learn: 0.2115312	total: 3.07s	remaining: 3.19s
# 98:	learn: 0.2109412	total: 3.11s	remaining: 3.17s
# 99:	learn: 0.2102946	total: 3.14s	remaining: 3.14s
# 100:	learn: 0.2095512	total: 3.17s	remaining: 3.11s
# 101:	learn: 0.2081688	total: 3.21s	remaining: 3.08s
# 102:	learn: 0.2076735	total: 3.24s	remaining: 3.05s
# 103:	learn: 0.2071036	total: 3.28s	remaining: 3.02s
# 104:	learn: 0.2056395	total: 3.31s	remaining: 3s
# 105:	learn: 0.2038594	total: 3.35s	remaining: 2.97s
# 106:	learn: 0.2037491	total: 3.39s	remaining: 2.94s
# 107:	learn: 0.2031595	total: 3.43s	remaining: 2.92s
# 108:	learn: 0.2013261	total: 3.46s	remaining: 2.89s
# 109:	learn: 0.2007632	total: 3.51s	remaining: 2.87s
# 110:	learn: 0.1985606	total: 3.55s	remaining: 2.84s
# 111:	learn: 0.1982398	total: 3.58s	remaining: 2.81s
# 112:	learn: 0.1974020	total: 3.62s	remaining: 2.79s
# 113:	learn: 0.1960048	total: 3.65s	remaining: 2.75s
# 114:	learn: 0.1945593	total: 3.69s	remaining: 2.73s
# 115:	learn: 0.1943479	total: 3.72s	remaining: 2.69s
# 116:	learn: 0.1932740	total: 3.76s	remaining: 2.67s
# 117:	learn: 0.1929169	total: 3.79s	remaining: 2.64s
# 118:	learn: 0.1925283	total: 3.83s	remaining: 2.61s
# 119:	learn: 0.1919029	total: 3.87s	remaining: 2.58s
# 120:	learn: 0.1913289	total: 3.9s	remaining: 2.55s
# 121:	learn: 0.1889048	total: 3.94s	remaining: 2.52s
# 122:	learn: 0.1876390	total: 3.98s	remaining: 2.49s
# 123:	learn: 0.1866833	total: 4.01s	remaining: 2.46s
# 124:	learn: 0.1853460	total: 4.05s	remaining: 2.43s
# 125:	learn: 0.1847943	total: 4.08s	remaining: 2.4s
# 126:	learn: 0.1834772	total: 4.12s	remaining: 2.37s
# 127:	learn: 0.1831641	total: 4.15s	remaining: 2.33s
# 128:	learn: 0.1829190	total: 4.2s	remaining: 2.31s
# 129:	learn: 0.1826389	total: 4.23s	remaining: 2.28s
# 130:	learn: 0.1822309	total: 4.27s	remaining: 2.25s
# 131:	learn: 0.1814539	total: 4.3s	remaining: 2.22s
# 132:	learn: 0.1803137	total: 4.34s	remaining: 2.19s
# 133:	learn: 0.1801401	total: 4.38s	remaining: 2.15s
# 134:	learn: 0.1779788	total: 4.41s	remaining: 2.12s
# 135:	learn: 0.1776316	total: 4.45s	remaining: 2.09s
# 136:	learn: 0.1772589	total: 4.48s	remaining: 2.06s
# 137:	learn: 0.1771251	total: 4.52s	remaining: 2.03s
# 138:	learn: 0.1758098	total: 4.56s	remaining: 2s
# 139:	learn: 0.1743577	total: 4.59s	remaining: 1.97s
# 140:	learn: 0.1735026	total: 4.62s	remaining: 1.94s
# 141:	learn: 0.1720835	total: 4.66s	remaining: 1.9s
# 142:	learn: 0.1715533	total: 4.7s	remaining: 1.87s
# 143:	learn: 0.1699486	total: 4.73s	remaining: 1.84s
# 144:	learn: 0.1683007	total: 4.76s	remaining: 1.81s
# 145:	learn: 0.1677770	total: 4.79s	remaining: 1.77s
# 146:	learn: 0.1671569	total: 4.83s	remaining: 1.74s
# 147:	learn: 0.1664146	total: 4.86s	remaining: 1.71s
# 148:	learn: 0.1655028	total: 4.9s	remaining: 1.68s
# 149:	learn: 0.1650929	total: 4.93s	remaining: 1.65s
# 150:	learn: 0.1647146	total: 4.97s	remaining: 1.61s
# 151:	learn: 0.1641989	total: 5.01s	remaining: 1.58s
# 152:	learn: 0.1637611	total: 5.05s	remaining: 1.55s
# 153:	learn: 0.1632200	total: 5.08s	remaining: 1.52s
# 154:	learn: 0.1624465	total: 5.11s	remaining: 1.48s
# 155:	learn: 0.1619226	total: 5.15s	remaining: 1.45s
# 156:	learn: 0.1618453	total: 5.18s	remaining: 1.42s
# 157:	learn: 0.1613401	total: 5.21s	remaining: 1.39s
# 158:	learn: 0.1611270	total: 5.25s	remaining: 1.35s
# 159:	learn: 0.1602619	total: 5.29s	remaining: 1.32s
# 160:	learn: 0.1596587	total: 5.33s	remaining: 1.29s
# 161:	learn: 0.1590486	total: 5.36s	remaining: 1.26s
# 162:	learn: 0.1585936	total: 5.4s	remaining: 1.23s
# 163:	learn: 0.1576475	total: 5.44s	remaining: 1.19s
# 164:	learn: 0.1575460	total: 5.5s	remaining: 1.17s
# 165:	learn: 0.1575105	total: 5.54s	remaining: 1.13s
# 166:	learn: 0.1568830	total: 5.57s	remaining: 1.1s
# 167:	learn: 0.1558490	total: 5.6s	remaining: 1.07s
# 168:	learn: 0.1558174	total: 5.64s	remaining: 1.03s
# 169:	learn: 0.1556165	total: 5.67s	remaining: 1s
# 170:	learn: 0.1549756	total: 5.71s	remaining: 968ms
# 171:	learn: 0.1543869	total: 5.75s	remaining: 936ms
# 172:	learn: 0.1541975	total: 5.79s	remaining: 904ms
# 173:	learn: 0.1534006	total: 5.82s	remaining: 870ms
# 174:	learn: 0.1521777	total: 5.86s	remaining: 837ms
# 175:	learn: 0.1510882	total: 5.9s	remaining: 804ms
# 176:	learn: 0.1506185	total: 5.93s	remaining: 771ms
# 177:	learn: 0.1495004	total: 5.96s	remaining: 737ms
# 178:	learn: 0.1493318	total: 5.99s	remaining: 703ms
# 179:	learn: 0.1487200	total: 6.03s	remaining: 670ms
# 180:	learn: 0.1485383	total: 6.06s	remaining: 636ms
# 181:	learn: 0.1472148	total: 6.09s	remaining: 602ms
# 182:	learn: 0.1455201	total: 6.12s	remaining: 569ms
# 183:	learn: 0.1450737	total: 6.15s	remaining: 535ms
# 184:	learn: 0.1435287	total: 6.18s	remaining: 501ms
# 185:	learn: 0.1420443	total: 6.22s	remaining: 468ms
# 186:	learn: 0.1410350	total: 6.25s	remaining: 435ms
# 187:	learn: 0.1406193	total: 6.29s	remaining: 401ms
# 188:	learn: 0.1400166	total: 6.32s	remaining: 368ms
# 189:	learn: 0.1396214	total: 6.35s	remaining: 334ms
# 190:	learn: 0.1392252	total: 6.39s	remaining: 301ms
# 191:	learn: 0.1385781	total: 6.42s	remaining: 267ms
# 192:	learn: 0.1383186	total: 6.46s	remaining: 234ms
# 193:	learn: 0.1379567	total: 6.49s	remaining: 201ms
# 194:	learn: 0.1374617	total: 6.53s	remaining: 167ms
# 195:	learn: 0.1365238	total: 6.56s	remaining: 134ms
# 196:	learn: 0.1362106	total: 6.59s	remaining: 100ms
# 197:	learn: 0.1358410	total: 6.63s	remaining: 66.9ms
# 198:	learn: 0.1356505	total: 6.66s	remaining: 33.5ms
# 199:	learn: 0.1347758	total: 6.7s	remaining: 0us
# 0:	learn: 0.6647525	total: 3.15ms	remaining: 312ms
# 1:	learn: 0.6411648	total: 6.06ms	remaining: 297ms
# 2:	learn: 0.6207454	total: 8.83ms	remaining: 286ms
# 3:	learn: 0.6046739	total: 11.2ms	remaining: 269ms
# 4:	learn: 0.5817083	total: 13.8ms	remaining: 262ms
# 5:	learn: 0.5624623	total: 16ms	remaining: 251ms
# 6:	learn: 0.5448052	total: 18.4ms	remaining: 245ms
# 7:	learn: 0.5314754	total: 20.9ms	remaining: 241ms
# 8:	learn: 0.5210811	total: 23.1ms	remaining: 233ms
# 9:	learn: 0.5118662	total: 25.2ms	remaining: 227ms
# 10:	learn: 0.5016699	total: 27.8ms	remaining: 225ms
# 11:	learn: 0.4920912	total: 30.3ms	remaining: 222ms
# 12:	learn: 0.4833407	total: 32.5ms	remaining: 217ms
# 13:	learn: 0.4762849	total: 35ms	remaining: 215ms
# 14:	learn: 0.4701015	total: 37.2ms	remaining: 211ms
# 15:	learn: 0.4645266	total: 39.4ms	remaining: 207ms
# 16:	learn: 0.4600196	total: 41.8ms	remaining: 204ms
# 17:	learn: 0.4564882	total: 44.1ms	remaining: 201ms
# 18:	learn: 0.4530926	total: 45.8ms	remaining: 195ms
# 19:	learn: 0.4492467	total: 48.3ms	remaining: 193ms
# 20:	learn: 0.4461769	total: 50.1ms	remaining: 188ms
# 21:	learn: 0.4429232	total: 52.3ms	remaining: 185ms
# 22:	learn: 0.4403676	total: 54.8ms	remaining: 183ms
# 23:	learn: 0.4377712	total: 57.1ms	remaining: 181ms
# 24:	learn: 0.4359834	total: 59.4ms	remaining: 178ms
# 25:	learn: 0.4342190	total: 62ms	remaining: 176ms
# 26:	learn: 0.4325450	total: 64.2ms	remaining: 174ms
# 27:	learn: 0.4306440	total: 66.5ms	remaining: 171ms
# 28:	learn: 0.4288562	total: 68.8ms	remaining: 168ms
# 29:	learn: 0.4279775	total: 70.3ms	remaining: 164ms
# 30:	learn: 0.4266036	total: 72.8ms	remaining: 162ms
# 31:	learn: 0.4258181	total: 74.3ms	remaining: 158ms
# 32:	learn: 0.4247675	total: 76.6ms	remaining: 155ms
# 33:	learn: 0.4236964	total: 78.8ms	remaining: 153ms
# 34:	learn: 0.4229259	total: 81ms	remaining: 150ms
# 35:	learn: 0.4220911	total: 83.4ms	remaining: 148ms
# 36:	learn: 0.4218026	total: 84.9ms	remaining: 145ms
# 37:	learn: 0.4212310	total: 87.1ms	remaining: 142ms
# 38:	learn: 0.4206584	total: 89.7ms	remaining: 140ms
# 39:	learn: 0.4203565	total: 91.8ms	remaining: 138ms
# 40:	learn: 0.4198846	total: 94.2ms	remaining: 136ms
# 41:	learn: 0.4196143	total: 96.6ms	remaining: 133ms
# 42:	learn: 0.4190736	total: 99.1ms	remaining: 131ms
# 43:	learn: 0.4189746	total: 101ms	remaining: 128ms
# 44:	learn: 0.4186078	total: 103ms	remaining: 126ms
# 45:	learn: 0.4182388	total: 105ms	remaining: 123ms
# 46:	learn: 0.4179627	total: 108ms	remaining: 121ms
# 47:	learn: 0.4178397	total: 109ms	remaining: 118ms
# 48:	learn: 0.4177327	total: 111ms	remaining: 116ms
# 49:	learn: 0.4173604	total: 114ms	remaining: 114ms
# 50:	learn: 0.4171098	total: 116ms	remaining: 112ms
# 51:	learn: 0.4168820	total: 118ms	remaining: 109ms
# 52:	learn: 0.4168801	total: 120ms	remaining: 107ms
# 53:	learn: 0.4167417	total: 123ms	remaining: 104ms
# 54:	learn: 0.4166177	total: 125ms	remaining: 102ms
# 55:	learn: 0.4165807	total: 127ms	remaining: 99.7ms
# 56:	learn: 0.4165348	total: 130ms	remaining: 98.2ms
# 57:	learn: 0.4160292	total: 133ms	remaining: 96.2ms
# 58:	learn: 0.4159792	total: 135ms	remaining: 94ms
# 59:	learn: 0.4157342	total: 138ms	remaining: 91.8ms
# 60:	learn: 0.4156386	total: 139ms	remaining: 89ms
# 61:	learn: 0.4154935	total: 142ms	remaining: 86.9ms
# 62:	learn: 0.4153172	total: 144ms	remaining: 84.5ms
# 63:	learn: 0.4150813	total: 146ms	remaining: 82.2ms
# 64:	learn: 0.4150509	total: 148ms	remaining: 79.9ms
# 65:	learn: 0.4148434	total: 151ms	remaining: 77.7ms
# 66:	learn: 0.4147312	total: 153ms	remaining: 75.4ms
# 67:	learn: 0.4143332	total: 156ms	remaining: 73.2ms
# 68:	learn: 0.4142531	total: 158ms	remaining: 70.9ms
# 69:	learn: 0.4141820	total: 160ms	remaining: 68.6ms
# 70:	learn: 0.4140442	total: 163ms	remaining: 66.4ms
# 71:	learn: 0.4138294	total: 165ms	remaining: 64.2ms
# 72:	learn: 0.4137924	total: 167ms	remaining: 61.9ms
# 73:	learn: 0.4136869	total: 170ms	remaining: 59.6ms
# 74:	learn: 0.4136775	total: 171ms	remaining: 57.2ms
# 75:	learn: 0.4135913	total: 174ms	remaining: 54.8ms
# 76:	learn: 0.4134451	total: 176ms	remaining: 52.6ms
# 77:	learn: 0.4133997	total: 179ms	remaining: 50.4ms
# 78:	learn: 0.4132961	total: 181ms	remaining: 48.1ms
# 79:	learn: 0.4132774	total: 183ms	remaining: 45.9ms
# 80:	learn: 0.4132624	total: 186ms	remaining: 43.6ms
# 81:	learn: 0.4130170	total: 188ms	remaining: 41.3ms
# 82:	learn: 0.4130167	total: 190ms	remaining: 38.9ms
# 83:	learn: 0.4130165	total: 192ms	remaining: 36.5ms
# 84:	learn: 0.4129622	total: 194ms	remaining: 34.2ms
# 85:	learn: 0.4129069	total: 196ms	remaining: 31.9ms
# 86:	learn: 0.4128392	total: 198ms	remaining: 29.6ms
# 87:	learn: 0.4128291	total: 201ms	remaining: 27.4ms
# 88:	learn: 0.4127932	total: 203ms	remaining: 25.1ms
# 89:	learn: 0.4127917	total: 205ms	remaining: 22.7ms
# 90:	learn: 0.4127728	total: 207ms	remaining: 20.5ms
# 91:	learn: 0.4127474	total: 209ms	remaining: 18.2ms
# 92:	learn: 0.4126770	total: 212ms	remaining: 15.9ms
# 93:	learn: 0.4125305	total: 214ms	remaining: 13.7ms
# 94:	learn: 0.4125276	total: 216ms	remaining: 11.4ms
# 95:	learn: 0.4124585	total: 219ms	remaining: 9.12ms
# 96:	learn: 0.4123917	total: 221ms	remaining: 6.84ms
# 97:	learn: 0.4123729	total: 223ms	remaining: 4.56ms
# 98:	learn: 0.4123715	total: 225ms	remaining: 2.27ms
# 99:	learn: 0.4122976	total: 227ms	remaining: 0us
#
# Лучшие параметры CatBoostClassifier: {'depth': 4, 'iterations': 100, 'l2_leaf_reg': 3, 'learning_rate': 0.1}
# Лучшая оценка ROC-AUC: 0.8425152932147972

# %% [markdown]
# ### LGBMClassifier

# %%
cat_pipeline = make_pipeline(
    OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
)

num_pipeline = make_pipeline(
    StandardScaler()
)

col_transf = ColumnTransformer(transformers=[
    ('num_pipeline', num_pipeline, numerical_cols),
    ('cat_pipeline', cat_pipeline, categorical_cols)
], n_jobs=-1)

lgbm_model = LGBMClassifier(random_state=RANDOM_STATE)

pipeline_lgbm = Pipeline(
    steps=[
        ('col_transf', col_transf),
        ('model_lgbm', lgbm_model)
    ]
)

param_lgbm = {
    'model_lgbm__learning_rate': [0.1, 0.2, 0.3, 0.5],
    'model_lgbm__max_depth': [4, 6, 8, 10],
    'model_lgbm__n_estimators': [10, 20, 50, 100, 150, 200],
    'model_lgbm__reg_alpha': [0.1, 1.0],
    'model_lgbm__reg_lambda': [0.1, 1.0],
    'model_lgbm__num_leaves': [10, 20]
}

grid_lgbm = GridSearchCV(pipeline_lgbm, param_grid=param_lgbm, cv=5,
                         n_jobs=-1, scoring='roc_auc')

grid_lgbm.fit(X_train, y_train)

best_params_lgbm = grid_lgbm.best_params_
score_lgbm = grid_lgbm.best_score_

print(f'\nЛучшие параметры LGBMClassifier: {best_params_lgbm}')
print(f'Лучшая оценка ROC-AUC: {score_lgbm}')

results = pd.concat([results, pd.DataFrame({
    'Model': ['LGBMClassifier'],
    'ROC-AUC': [score_lgbm]
})], ignore_index=True)
# Out:
# Лучшие параметры LGBMClassifier: {'model_lgbm__learning_rate': 0.2, 'model_lgbm__max_depth': 4, 'model_lgbm__n_estimators': 20, 'model_lgbm__num_leaves': 10, 'model_lgbm__reg_alpha': 0.1, 'model_lgbm__reg_lambda': 0.1}
# Лучшая оценка ROC-AUC: 0.8416715551104911

# %% [markdown]
# ### Выбор лучшей модели

# %%
# Выведем результаты обучения моделей
results
# Out:
#                     Model   ROC-AUC
# 0  RandomForestClassifier  0.835994
# 1      CatBoostClassifier  0.842515
# 2          LGBMClassifier  0.841672

# %% [markdown]
# Все модели дали примерно одинаковый результат.
# Модель CatBoostClassifier показала чуть более лучший результатметрика качества ROC-AUC 0.842515.
#
# Эту модель берем для предсказаний на тестовой выборке.

# %% [markdown]
# ### Вывод

# %% [markdown]
# На этапе подготовки данных к обучению:
#
# * Разделили датасет на тренировочную и тестовые выборки. Разделим модель на обучающую и тестовую выборки (test_size = 0.25). Добавим параметр stratify, чтобы отношение данных целевого признака в подвыборках было одинаковым. Это важно, так как наша целевая переменная 'contract_terminated' несбалансирована.
#
# * Выбрали модели для обучения на тренировочных данных:
#
#     * RandomForestClassifier
#     * CatBoostClassifier
#     * LGBMClassifier
#
# * Обучили выбранные модели на тренировочных данных.
# * Оценивали качество моделей метрикой ROC-AUC.
#
# * Получили результаты обучения со следующими показателями ROC-AUC:
#     * RandomForestClassifier	0.835994
#     * CatBoostClassifier	0.842515
#     * LGBMClassifier	0.841672
#
# * Все модели дали примерно одинаковый результат. Модель CatBoostClassifier показала чуть более лучший результат, метрика качества ROC-AUC 0.8425:
#     * 'depth': 4,
#     * 'iterations': 100,
#     * 'l2_leaf_reg': 3,
#     * 'learning_rate': 0.1
#
# Эту модель берем для предсказаний на тестовой выборке.

# %% [markdown]
# # Обучение лучшей модели и предсказание на тестовой выборке

# %% [markdown]
# * Проверьте качество лучшей модели на тестовой выборке. Значение метрики ROC-AUC должно быть не менее 0.85.
# Для интерпретируемости модели дополнительно выведите значение accuracy.
#
# * Постройте матрицу ошибок лучшей модели. Отобразите полноту и точность модели на графике.
#
# * Проанализируйте важность основных входных признаков, влияющих на отток клиентов.
#
# * Для одного из важных входных признаков проведите дополнительное исследование:
# Покажите график зависимости входного и целевого признаков.

# %%
# Обучим модель с лучшими гиперпараметрами
best_catboost_model = grid_catboost.best_estimator_

# Предскажем на тестовой выборке вероятности
y_pred_proba = best_catboost_model.predict_proba(X_test)[:, 1]

# Предскажем на тестовой выборке классы
y_pred = best_catboost_model.predict(X_test)

# Расчет ROC-AUC
roc_auc = roc_auc_score(y_test, y_pred_proba)

# Расчет accuracy
accuracy = accuracy_score(y_test, y_pred)

print(f'ROC-AUC на тестовой выборке: {roc_auc}')
print(f'Accuracy на тестовой выборке: {accuracy}')
# Out:
# ROC-AUC на тестовой выборке: 0.8511506177496935
# Accuracy на тестовой выборке: 0.8038879359634077

# %% [markdown]
# * Проверили качество лучшей модели CatBoostClassifier на тестовой выборке. Получили значение **ROC-AUC 0.8511**, что отвечает требованиям задачи (значение метрики ROC-AUC должно быть не менее 0.85). Это означает, что в 85.1% случаев модель правильно различает положительные (отток) и отрицательные (нет оттока) классы.
#
# * Для интерпретируемости модели дополнительно получили значение **Accuracy 0.8039**. Accuracy измеряет долю правильных предсказаний (классов 1 и 0) от общего числа предсказаний. В нашем случае это означает, что 80.4% всех предсказаний модели были верными.

# %% [markdown]
# Дополнительно построим ROC-кривую (Receiver Operating Characteristic Curve) - график для оценки качества бинарного классификатора.

# %%
# Построение ROC-кривой
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# Кривая ROC показывает соотношение TPR (True Positive Rate) и FPR (False Positive Rate) при различных порогах классификации.
# Кривая, близкая к верхнему левому углу, указывает на высокое качество модели. У нас это значение 0.85 из 1, что является хорошим показателем.

# %% [markdown]
# ## Матрица ошибок лучшей модели

# %% [markdown]
# Дополнительно построим матрицу ошибок лучшей модели.

# %%
skplt.metrics.plot_confusion_matrix(y_test, y_pred, normalize=True)
plt.show()

# Построение матрицы ошибок
conf_matrix = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Не разорвал договор', 'Разорвал договор'],
            yticklabels=['Не разорвал договор', 'Разорвал договор'])
plt.xlabel('Предсказано')
plt.ylabel('Истина')
plt.title('Матрица ошибок')
plt.show()

# %% [markdown]
# Согласно матрице ошибок показатель True Positives (TP) довольно высок, это означает, что наша модель в 92% случаев верно предсказывает что клиент не разорвет договор, модель ошибается в данном случае только на 8%.
#
# Что касается оценки True Negatives (TN), тут модель только в 49% правильно определяет отток клиентов, ошибается в 51% случаев.
#
# Учитывая эту информацию, наша модель не столь эффективна, так как для клиента критичнее получать предсказания того, что клиент разорвет договор.
#
#
#
# Отобразим график полноты и точности модели.

# %%
# Получим вероятность класса 1
probs = best_catboost_model.predict_proba(X_test)[:, 1]

# Вычислим precision и recall
precision, recall, _ = precision_recall_curve(y_test, probs)

# Построим кривую precision-recall
pr_display = PrecisionRecallDisplay(precision=precision, recall=recall).plot()
plt.gcf().set_size_inches(8, 6)
plt.title('Precision-Recall Curve')
plt.show()

# %% [markdown]
# Линия спускается по мере увеличения recall, что указывает на то, что часть положительных объектов класса 1 была правильно определена, но вместе с тем уменьшается точность (precision). Это означает, что при увеличении recall модель делает больше ошибок и классифицирует некоторые негативные объекты как положительные.
#
# Когда recall достигает 1 (все положительные объекты были правильно определены), precision уменьшается до 0.25, что означает, что среди всех объектов, которые модель предсказала как положительные, только 25% действительно принадлежат к классу 1. Это довольно низкий показатель.

# %% [markdown]
# ## Анализ важности входных признаков

# %% [markdown]
# Проанализируем важность основных входных признаков, влияющих на отток клиентов.

# %%
# Извлечение модели catboost из пайплайна
if hasattr(best_catboost_model, 'named_steps'):
    catboost_model = best_catboost_model.named_steps['model_lgbm']
else:
    catboost_model = best_catboost_model

# Вычисление важности признаков
feature_importance = catboost_model.feature_importances_

# Создадим DataFrame
importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importance})

# Отсортируем признаки по важности
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Выведем топ-10 важных признаков
top_n = 10
print(f'Top {top_n} важных признаков:')
print(importance_df.head(top_n))

plt.figure(figsize=(10, 6))
plt.barh(importance_df['Feature'][:top_n], importance_df['Importance'][:top_n], color='teal')
plt.xlabel('Важность')
plt.ylabel('Признаки')
plt.title('Top 10 важных признаков')
plt.gca().invert_yaxis()
plt.show()
# Out:
# Top 10 важных признаков:
#               Feature  Importance
# 7    internet_service   30.439826
# 3       total_charges   24.373435
# 0                type   19.565611
# 8     online_security    6.588852
# 1   paperless_billing    6.585575
# 2      payment_method    3.827409
# 11       tech_support    3.313852
# 4      senior_citizen    1.870555
# 9       online_backup    1.782018
# 6          dependents    1.603884

# %% [markdown]
# Наиболее важными признаками, оказавшими влияние на предсказание оттока клиентов, являются:
#
# 1. internet_service   - 30.439826
# 2. total_charges  - 24.373435
# 3. type  - 19.565611
# 4. online_security  -  6.588852
# 5. paperless_billing  -  6.585575
# 6. payment_method  -  3.827409
# 7. tech_support  -  3.313852
# 8. senior_citizen  -  1.870555
# 9. online_backup  -  1.782018
# 10. dependents  -  1.603884

# %% [markdown]
# ## График зависимости самого важного фактора и целевой переменной

# %% [markdown]
# Построим график зависимости входного (internet_service) и целевого признаков (contract_terminated).

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='internet_service', hue='contract_terminated', data=data)
plt.title('Зависимость между типом подключения и разрывом договора')
plt.xlabel('Тип оплаты')
plt.ylabel('Количество')
plt.legend(title='Разорвал договор', labels=['Не разорвал', 'Разорвал'])
plt.show()

# %% [markdown]
# На графике видим, что клиенты, использующие подключение интернета fiber optic гораздо чаще разрывают договора, чем клиенты с другим подключением или без интернет-подключения.

# %% [markdown]
# Дополнительно проверим лучшую модель на адекватность с помощью константной модели DummyClassifier

# %%
# Создадим константную модель, предсказывающий наиболее часто встречающийся класс
dummy_model = DummyClassifier(strategy="most_frequent")

# Обучим константную модель
dummy_model.fit(X_train, y_train)

# Предскажем на тестовой выборке
y_pred_dummy = dummy_model.predict(X_test)

roc_auc_dummy = roc_auc_score(y_test, dummy_model.predict_proba(X_test)[:, 1])
accuracy_dummy = accuracy_score(y_test, y_pred_dummy)

print(f'ROC-AUC константной модели: {roc_auc_dummy}')
print(f'Accuracy константной модели: {accuracy_dummy}')
# Out:
# ROC-AUC константной модели: 0.5
# Accuracy константной модели: 0.73642081189251

# %% [markdown]
# ROC-AUC константной модели DummyClassifier 0.5, что ниже результата тестирования нашей лучшей модели на тестовой выборке. Это говорит об адекватности выбранной нами модели.

# %% [markdown]
# ## Вывод

# %% [markdown]
# * Для поиска лучшей модели, предсказывающий отток клиентов, были протестированы:
#
#     * RandomForestClassifier
#     * CatBoostClassifier
#     * LGBMClassifier
#
# * Были получены результаты обучения со следующими показателями ROC-AUC:
#
#     * RandomForestClassifier	0.835994
#     * CatBoostClassifier	0.842515
#     * LGBMClassifier	0.841672
#
# * Модель CatBoostClassifier показала чуть более лучший результат, метрика качества ROC-AUC 0.848442. Лучшие гиперпараметры:
#
#     * 'depth': 4,
#     * 'iterations': 100,
#     * 'l2_leaf_reg': 3,
#     * 'learning_rate': 0.1
#
# Эту модель брали для предсказаний на тестовой выборке.
#
# * Проверили качество лучшей модели CatBoostClassifier на тестовой выборке. Получили значение **ROC-AUC 0.8511**, что отвечает требованиям задачи (значение метрики ROC-AUC должно быть не менее 0.85). Это означает, что в 85.1% случаев модель правильно различает положительные (отток) и отрицательные (нет оттока) классы.
#
# * Для интерпретируемости модели дополнительно получили значение **Accuracy 0.8039**. Accuracy измеряет долю правильных предсказаний (классов 1 и 0) от общего числа предсказаний. В нашем случае это означает, что 80.4% всех предсказаний модели были верными.
#
# * Построили Матрицу ошибок. Показатель True Positives (TP) довольно высок, это означает, что наша модель в 91% случаев верно предсказывает, что клиент не разорвет договор, модель ошибается в данном случае только на 9%. Что касается оценки True Negatives (TN), тут модель только в 49% правильно определяет отток клиентов, ошибается в 51% случаев.
#
# * Построили график полноты и точности модели.
# Линия на графике спускается по мере увеличения recall, что указывает на то, что часть положительных объектов класса 1 была правильно определена, но вместе с тем уменьшается точность (precision). Это означает, что при увеличении recall модель делает больше ошибок и классифицирует некоторые негативные объекты как положительные.
# Когда recall достигает 1 (все положительные объекты были правильно определены), precision уменьшается до 0.25, что означает, что среди всех объектов, которые модель предсказала как положительные, только 25% действительно принадлежат к классу 1.
#
# * Проанализировали важность основных входных признаков, влияющих на отток клиентов.
# Наиболее важными признаками, оказавшими влияние на предсказание оттока клиентов, являются:
#
# 1. internet_service   - 30.439826
# 2. total_charges  - 24.373435
# 3. type  - 19.565611
# 4. online_security  -  6.588852
# 5. paperless_billing  -  6.585575
# 6. payment_method  -  3.827409
# 7. tech_support  -  3.313852
# 8. senior_citizen  -  1.870555
# 9. online_backup  -  1.782018
# 10. dependents  -  1.603884
#
# * Построили график зависимости входного признака (internet_service) и целевого (contract_terminated).
# На графике видим, что клиенты, использующие подключение интернета fiber optic гораздо чаще разрывают договора, чем клиенты с другим подключением или без интернет-подключения.
#
# Учитывая всю информацию, наша итоговая модель не столь эффективна, так как нам важнее получать предсказания того, что клиент разорвет договор. Однако наша модель делает довольно много ошибок в предсказании класса 1.
#
# Это связано с тем, что у нас изначально довольно мало данных о клиентах, разорвавших договор (дисбаланс классов в целевом признаке).
#
# В качестве рекомендаций улучшения модели и предсказания класса 1 можно попробовать:
#
# * Запросить у клиента больше исторических данных о клиентах, разорвавших договор и попробовать обучить модели снова.
# * Можно попробовать совместить балансировку с кросс-валидацией (SMOTE, RanomOverSampler/RanomUnderSampler).
# * Создать новые признаки на основе имеющихся данных
#
#
# В качестве бизнес-рекомендаций, основанных на исследовании и работы модели, заказчику можно предложить:
#
# * Разработать и внедрить персонализированные предложения для клиентов, которые с высокой вероятностью могут разорвать договор. Это могут быть скидки, специальные условия или улучшенные тарифы.
# * Оптимизировать предложения на основе сегментации клиентов по ключевым признакам (например, тип оплаты, наличие дополнительных услуг).
# * Внедрить системы проактивного обслуживания клиентов, которая будет автоматически связываться с клиентами с высоким риском оттока и предлагать им помощь или дополнительные услуги.
# * Улучить обратную связь с клиентами для выяснения причин недовольства и устранение этих причин.
# * Разработать программы лояльности для удержания клиентов, таких как бонусные программы, накопительные скидки или эксклюзивные предложения для долгосрочных клиентов.
# * Обновить и улучшить тарифные планы и дополнительные услуги, чтобы они лучше соответствовали потребностям клиентов.
